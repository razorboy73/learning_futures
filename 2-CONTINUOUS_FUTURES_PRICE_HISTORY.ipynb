# %%
import os
import time
from datetime import datetime
from typing import Optional, Dict, Any, List, Tuple

import numpy as np
import pandas as pd
import norgatedata


"""
===============================================================================
DOWNLOAD FULL NORGATE CONTINUOUS FUTURES PRICE HISTORY (per instrument)
===============================================================================

Reads the futures universe produced by your Norgate universe builder and
downloads continuous price series (e.g. &ES) for every instrument with data.

Outputs (per instrument):
- CSV:    OUTPUT_DIR/csv/<SYMBOL>.csv
- Parquet OUTPUT_DIR/parquet/<SYMBOL>.parquet

Optional consolidated outputs:
- CSV:    OUTPUT_DIR/norgate_continuous_all.csv
- Parquet OUTPUT_DIR/norgate_continuous_all.parquet

Diagnostics:
- No price data
- < MIN_DAYS_AFTER_START after START_DATE
- Last price date older than STALE_DAYS
- Very late start (possible limited history)
- Short full history
- Large gaps in trading history (> GAP_DAYS)
- Optional suspicious jumps (very large daily returns)

Requirements:
- Norgate Data Updater (NDU) running
- norgatedata package installed
- continuous_contracts.csv from your universe builder

===============================================================================
"""


# ============================================================
# 1. CONFIG
# ============================================================
CONTINUOUS_LIST_PATH = "./01-futures_universe/continuous_contracts.csv"

OUTPUT_DIR = "./02-futures_prices/norgate_continuous"
CSV_DIR = os.path.join(OUTPUT_DIR, "csv")
PARQUET_DIR = os.path.join(OUTPUT_DIR, "parquet")
os.makedirs(CSV_DIR, exist_ok=True)
os.makedirs(PARQUET_DIR, exist_ok=True)

# Consolidated output toggles
SAVE_ALL_PARQUET = True
SAVE_ALL_CSV = True
ALL_PARQUET_PATH = os.path.join(OUTPUT_DIR, "norgate_continuous_all.parquet")
ALL_CSV_PATH = os.path.join(OUTPUT_DIR, "norgate_continuous_all.csv")

# Date range
START_DATE = pd.Timestamp("1998-01-01")
END_DATE = None  # None = up to most recent available

# Diagnostics thresholds
MIN_DAYS_AFTER_START = 100
STALE_DAYS = 30
LATE_START_YEAR = 2015
EARLY_TERMINATION_MIN_TOTAL_DAYS = 250 * 5  # < ~5y
GAP_DAYS = 10

# Optional: flag very large daily moves (helps catch bad stitching/roll artifacts)
ENABLE_JUMP_CHECK = True
JUMP_Z_THRESHOLD = 8.0  # z-score on daily returns
MIN_RET_OBS_FOR_Z = 252

# Throttle (usually not needed for local Norgate, but keep small pause)
SLEEP_SECONDS = 0.05

# Parquet compression (good default)
PARQUET_COMPRESSION = "snappy"


# ============================================================
# 2. UTILITIES
# ============================================================
def print_flag(symbol: str, message: str) -> None:
    print(f"⚠ {symbol}: {message}")


def ensure_ndu_running() -> None:
    if not norgatedata.status():
        raise RuntimeError(
            "Norgate Data Updater (NDU) is not running. Start NDU and retry."
        )


def fetch_timeseries(
    continuous_symbol: str,
    start_date: pd.Timestamp,
    end_date: Optional[pd.Timestamp],
) -> pd.DataFrame:
    """
    Fetch continuous futures timeseries from Norgate.
    Returns a DataFrame indexed by date with OHLCV columns (depending on availability).
    """
    kwargs: Dict[str, Any] = dict(
        symbol=continuous_symbol,
        start_date=str(start_date.date()),
        format="pandas-dataframe",
    )
    if end_date is not None:
        kwargs["end_date"] = str(end_date.date())

    df = norgatedata.price_timeseries(**kwargs)
    if df is None or len(df) == 0:
        return pd.DataFrame()

    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index)

    df = df.sort_index()
    df.index.name = "date"

    # Normalize column names
    df.columns = [c.strip().lower() for c in df.columns]

    return df


def detect_large_gaps(dates: pd.DatetimeIndex, gap_days: int) -> Optional[int]:
    if len(dates) < 2:
        return None
    gaps = pd.Series(dates).diff().dt.days
    if (gaps > gap_days).any():
        return int(gaps.max())
    return None


def jump_check(df: pd.DataFrame) -> Optional[Tuple[float, pd.Timestamp]]:
    """
    Flags extremely large daily returns by z-score.
    Uses 'close' if present, else tries 'settle' or last column fallback.
    """
    if not ENABLE_JUMP_CHECK:
        return None

    price_col = None
    for candidate in ["close", "settle", "last"]:
        if candidate in df.columns:
            price_col = candidate
            break
    if price_col is None:
        numeric_cols = [c for c in df.columns if pd.api.types.is_numeric_dtype(df[c])]
        if not numeric_cols:
            return None
        price_col = numeric_cols[0]

    px = df[price_col].astype(float).replace([np.inf, -np.inf], np.nan).dropna()
    if len(px) < max(MIN_RET_OBS_FOR_Z, 20):
        return None

    rets = px.pct_change().dropna()
    if len(rets) < MIN_RET_OBS_FOR_Z:
        return None

    mu = rets.mean()
    sig = rets.std(ddof=1)
    if sig == 0 or np.isnan(sig):
        return None

    z = (rets - mu) / sig
    zmax = float(z.abs().max())
    if zmax >= JUMP_Z_THRESHOLD:
        dt = z.abs().idxmax()
        return zmax, pd.Timestamp(dt)

    return None


def load_continuous_universe(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    required = {"symbol", "continuous_symbol"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"Universe file missing columns: {sorted(missing)}")

    # Keep only those marked as having data if present
    if "data_points" in df.columns:
        df = df[df["data_points"].fillna(0) > 0]

    df["symbol"] = df["symbol"].astype(str).str.strip().str.upper()
    df["continuous_symbol"] = df["continuous_symbol"].astype(str).str.strip()

    df = df.drop_duplicates(subset=["symbol", "continuous_symbol"]).reset_index(drop=True)
    return df


# ============================================================
# 3. MAIN
# ============================================================
def main() -> None:
    print("=" * 79)
    print("DOWNLOAD FULL NORGATE CONTINUOUS FUTURES PRICE HISTORY")
    print("=" * 79)
    print("Run timestamp:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

    ensure_ndu_running()

    print("\nLoading continuous universe:", CONTINUOUS_LIST_PATH)
    uni = load_continuous_universe(CONTINUOUS_LIST_PATH)
    print(f"✔ Loaded {len(uni)} continuous instruments")

    all_rows: List[pd.DataFrame] = []
    today = pd.Timestamp.today().normalize()

    print("\nDownloading + saving per-instrument CSV + Parquet + running diagnostics…\n")

    for _, row in uni.iterrows():
        sym = row["symbol"]
        csym = row["continuous_symbol"]

        try:
            df = fetch_timeseries(csym, START_DATE, END_DATE)
        except Exception as e:
            print_flag(sym, f"ERROR fetching {csym}: {str(e)[:120]}")
            continue

        if df.empty:
            print_flag(sym, f"NO PRICE DATA RECEIVED for {csym}")
            time.sleep(SLEEP_SECONDS)
            continue

        # --- Save per instrument CSV + Parquet
        csv_path = os.path.join(CSV_DIR, f"{sym}.csv")
        pq_path = os.path.join(PARQUET_DIR, f"{sym}.parquet")

        df.to_csv(csv_path)
        df.to_parquet(pq_path, compression=PARQUET_COMPRESSION)

        print(f"Saved: {csv_path}")
        print(f"Saved: {pq_path}")

        # --- Optional consolidated storage
        if SAVE_ALL_PARQUET or SAVE_ALL_CSV:
            tmp = df.copy()
            tmp.insert(0, "symbol", sym)
            tmp.insert(1, "continuous_symbol", csym)
            all_rows.append(tmp.reset_index())

        # ========================================================
        # DIAGNOSTICS
        # ========================================================
        df_after = df.loc[df.index >= START_DATE]
        n_days = len(df_after)
        if n_days < MIN_DAYS_AFTER_START:
            last_day = df_after.index.max() if n_days > 0 else None
            print_flag(
                sym,
                f"LESS THAN {MIN_DAYS_AFTER_START} DAYS after {START_DATE.date()} — "
                f"{n_days} days (last date = {last_day.date() if last_day is not None else None})"
            )

        first_dt = df.index.min()
        if first_dt.year > LATE_START_YEAR:
            print_flag(sym, f"Very late start — first date is {first_dt.date()}")

        last_dt = df.index.max()
        if last_dt < today - pd.Timedelta(days=STALE_DAYS):
            print_flag(sym, f"Data ends at {last_dt.date()} — older than {STALE_DAYS} days")

        full_days = len(df)
        if full_days < EARLY_TERMINATION_MIN_TOTAL_DAYS:
            print_flag(sym, f"Short full history (<~5y) — only {full_days} trading days total.")

        max_gap = detect_large_gaps(df.index, GAP_DAYS)
        if max_gap is not None:
            print_flag(sym, f"LARGE GAP in data — max gap = {max_gap} days")

        jc = jump_check(df)
        if jc is not None:
            zmax, jdate = jc
            print_flag(sym, f"SUSPICIOUS JUMP — max |z(ret)|={zmax:.1f} on {jdate.date()}")

        time.sleep(SLEEP_SECONDS)

    # --- Write consolidated outputs
    if (SAVE_ALL_PARQUET or SAVE_ALL_CSV) and all_rows:
        big = pd.concat(all_rows, ignore_index=True)

        if SAVE_ALL_PARQUET:
            big.to_parquet(ALL_PARQUET_PATH, index=False, compression=PARQUET_COMPRESSION)
            print(f"\n✔ Saved consolidated Parquet → {ALL_PARQUET_PATH}")

        if SAVE_ALL_CSV:
            big.to_csv(ALL_CSV_PATH, index=False)
            print(f"✔ Saved consolidated CSV → {ALL_CSV_PATH}")

    print("\n" + "=" * 79)
    print("DONE — Norgate continuous futures history saved per instrument")
    print("CSV folder:   ", CSV_DIR)
    print("Parquet folder:", PARQUET_DIR)
    print("=" * 79)


if __name__ == "__main__":
    main()
# Out:
# ===============================================================================
# DOWNLOAD FULL NORGATE CONTINUOUS FUTURES PRICE HISTORY
# ===============================================================================
# Run timestamp: 2026-01-28 18:03:35
#
# Loading continuous universe: ./01-futures_universe/continuous_contracts.csv
# ✔ Loaded 105 continuous instruments
#
# Downloading + saving per-instrument CSV + Parquet + running diagnostics…
#
# Saved: ./02-futures_prices/norgate_continuous\csv\RS.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\RS.parquet
# ⚠ RS: Very late start — first date is 2024-01-22
# ⚠ RS: Short full history (<~5y) — only 505 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZW.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZW.parquet
# ⚠ ZW: Very late start — first date is 2024-01-22
# ⚠ ZW: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\DC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\DC.parquet
# ⚠ DC: Very late start — first date is 2024-01-22
# ⚠ DC: Short full history (<~5y) — only 507 trading days total.
# ⚠ DC: SUSPICIOUS JUMP — max |z(ret)|=11.6 on 2024-04-30
# Saved: ./02-futures_prices/norgate_continuous\csv\CC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\CC.parquet
# ⚠ CC: Very late start — first date is 2024-01-22
# ⚠ CC: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\KC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\KC.parquet
# ⚠ KC: Very late start — first date is 2024-01-22
# ⚠ KC: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZC.parquet
# ⚠ ZC: Very late start — first date is 2024-01-22
# ⚠ ZC: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\CT.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\CT.parquet
# ⚠ CT: Very late start — first date is 2024-01-22
# ⚠ CT: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\AFB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\AFB.parquet
# ⚠ AFB: Very late start — first date is 2024-01-22
# ⚠ AFB: Short full history (<~5y) — only 518 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\AWM.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\AWM.parquet
# ⚠ AWM: Very late start — first date is 2024-01-22
# ⚠ AWM: Short full history (<~5y) — only 518 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\LWB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LWB.parquet
# ⚠ LWB: Very late start — first date is 2024-01-22
# ⚠ LWB: Short full history (<~5y) — only 511 trading days total.
# ⚠ LWB: SUSPICIOUS JUMP — max |z(ret)|=10.9 on 2024-04-24
# Saved: ./02-futures_prices/norgate_continuous\csv\GF.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\GF.parquet
# ⚠ GF: Very late start — first date is 2024-01-22
# ⚠ GF: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\OJ.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\OJ.parquet
# ⚠ OJ: Very late start — first date is 2024-01-22
# ⚠ OJ: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\MWE.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\MWE.parquet
# ⚠ MWE: Very late start — first date is 2024-01-22
# ⚠ MWE: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\KE.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\KE.parquet
# ⚠ KE: Very late start — first date is 2024-01-22
# ⚠ KE: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\HE.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\HE.parquet
# ⚠ HE: Very late start — first date is 2024-01-22
# ⚠ HE: Short full history (<~5y) — only 507 trading days total.
# ⚠ HE: SUSPICIOUS JUMP — max |z(ret)|=9.4 on 2025-08-14
# Saved: ./02-futures_prices/norgate_continuous\csv\LE.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LE.parquet
# ⚠ LE: Very late start — first date is 2024-01-22
# ⚠ LE: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\LCC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LCC.parquet
# ⚠ LCC: Very late start — first date is 2024-01-22
# ⚠ LCC: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\LBR.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LBR.parquet
# ⚠ LBR: Very late start — first date is 2024-01-22
# ⚠ LBR: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZO.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZO.parquet
# ⚠ ZO: Very late start — first date is 2024-01-22
# ⚠ ZO: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\LRC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LRC.parquet
# ⚠ LRC: Very late start — first date is 2024-01-22
# ⚠ LRC: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZR.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZR.parquet
# ⚠ ZR: Very late start — first date is 2024-01-22
# ⚠ ZR: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZS.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZS.parquet
# ⚠ ZS: Very late start — first date is 2024-01-22
# ⚠ ZS: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZM.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZM.parquet
# ⚠ ZM: Very late start — first date is 2024-01-22
# ⚠ ZM: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZL.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZL.parquet
# ⚠ ZL: Very late start — first date is 2024-01-22
# ⚠ ZL: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\SB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SB.parquet
# ⚠ SB: Very late start — first date is 2024-01-22
# ⚠ SB: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\LSU.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LSU.parquet
# ⚠ LSU: Very late start — first date is 2024-01-22
# ⚠ LSU: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6A.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6A.parquet
# ⚠ 6A: Very late start — first date is 2024-01-22
# ⚠ 6A: Short full history (<~5y) — only 507 trading days total.
# ⚠ 6A: SUSPICIOUS JUMP — max |z(ret)|=8.7 on 2025-04-04
# Saved: ./02-futures_prices/norgate_continuous\csv\BTC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\BTC.parquet
# ⚠ BTC: Very late start — first date is 2024-01-22
# ⚠ BTC: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6B.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6B.parquet
# ⚠ 6B: Very late start — first date is 2024-01-22
# ⚠ 6B: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6C.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6C.parquet
# ⚠ 6C: Very late start — first date is 2024-01-22
# ⚠ 6C: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ETH.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ETH.parquet
# ⚠ ETH: Very late start — first date is 2024-01-22
# ⚠ ETH: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6E.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6E.parquet
# ⚠ 6E: Very late start — first date is 2024-01-22
# ⚠ 6E: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6J.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6J.parquet
# ⚠ 6J: Very late start — first date is 2024-01-22
# ⚠ 6J: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6M.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6M.parquet
# ⚠ 6M: Very late start — first date is 2024-01-22
# ⚠ 6M: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\MBT.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\MBT.parquet
# ⚠ MBT: Very late start — first date is 2024-01-22
# ⚠ MBT: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\MET.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\MET.parquet
# ⚠ MET: Very late start — first date is 2024-01-22
# ⚠ MET: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6N.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6N.parquet
# ⚠ 6N: Very late start — first date is 2024-01-22
# ⚠ 6N: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\6S.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\6S.parquet
# ⚠ 6S: Very late start — first date is 2024-01-22
# ⚠ 6S: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\DX.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\DX.parquet
# ⚠ DX: Very late start — first date is 2024-01-22
# ⚠ DX: Short full history (<~5y) — only 521 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\BRN.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\BRN.parquet
# ⚠ BRN: Very late start — first date is 2024-01-22
# ⚠ BRN: Short full history (<~5y) — only 521 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\CL.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\CL.parquet
# ⚠ CL: Very late start — first date is 2024-01-22
# ⚠ CL: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\NG.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\NG.parquet
# ⚠ NG: Very late start — first date is 2024-01-22
# ⚠ NG: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\GAS.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\GAS.parquet
# ⚠ GAS: Very late start — first date is 2024-01-22
# ⚠ GAS: Short full history (<~5y) — only 521 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\HO.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\HO.parquet
# ⚠ HO: Very late start — first date is 2024-01-22
# ⚠ HO: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\RB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\RB.parquet
# ⚠ RB: Very late start — first date is 2024-01-22
# ⚠ RB: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\GWM.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\GWM.parquet
# ⚠ GWM: Very late start — first date is 2024-01-22
# ⚠ GWM: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\WBS.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\WBS.parquet
# ⚠ WBS: Very late start — first date is 2024-01-22
# ⚠ WBS: Short full history (<~5y) — only 521 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\CGB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\CGB.parquet
# ⚠ CGB: Very late start — first date is 2024-01-22
# ⚠ CGB: Short full history (<~5y) — only 503 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZN.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZN.parquet
# ⚠ ZN: Very late start — first date is 2024-01-22
# ⚠ ZN: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ZT.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZT.parquet
# ⚠ ZT: Very late start — first date is 2024-01-22
# ⚠ ZT: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\SR3.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SR3.parquet
# ⚠ SR3: Very late start — first date is 2024-01-22
# ⚠ SR3: Short full history (<~5y) — only 507 trading days total.
# ⚠ SR3: SUSPICIOUS JUMP — max |z(ret)|=14.2 on 2024-09-17
# Saved: ./02-futures_prices/norgate_continuous\csv\SO3.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SO3.parquet
# ⚠ SO3: Very late start — first date is 2024-01-22
# ⚠ SO3: Short full history (<~5y) — only 511 trading days total.
# ⚠ SO3: SUSPICIOUS JUMP — max |z(ret)|=11.6 on 2024-09-17
# Saved: ./02-futures_prices/norgate_continuous\csv\ZQ.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZQ.parquet
# ⚠ ZQ: Very late start — first date is 2024-01-22
# ⚠ ZQ: Short full history (<~5y) — only 507 trading days total.
# ⚠ ZQ: SUSPICIOUS JUMP — max |z(ret)|=13.0 on 2024-09-30
# Saved: ./02-futures_prices/norgate_continuous\csv\ZF.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZF.parquet
# ⚠ ZF: Very late start — first date is 2024-01-22
# ⚠ ZF: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\YXT.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\YXT.parquet
# ⚠ YXT: Very late start — first date is 2024-01-22
# ⚠ YXT: Short full history (<~5y) — only 518 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\YYT.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\YYT.parquet
# ⚠ YYT: Very late start — first date is 2024-01-22
# ⚠ YYT: Short full history (<~5y) — only 518 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\YIB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\YIB.parquet
# ⚠ YIB: Very late start — first date is 2024-01-22
# ⚠ YIB: Short full history (<~5y) — only 518 trading days total.
# ⚠ YIB: SUSPICIOUS JUMP — max |z(ret)|=9.7 on 2025-07-08
# Saved: ./02-futures_prices/norgate_continuous\csv\YIR.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\YIR.parquet
# ⚠ YIR: Very late start — first date is 2024-01-22
# ⚠ YIR: Short full history (<~5y) — only 518 trading days total.
# ⚠ YIR: SUSPICIOUS JUMP — max |z(ret)|=9.1 on 2025-06-12
# Saved: ./02-futures_prices/norgate_continuous\csv\LEU.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LEU.parquet
# ⚠ LEU: Very late start — first date is 2024-01-22
# ⚠ LEU: Short full history (<~5y) — only 515 trading days total.
# ⚠ LEU: SUSPICIOUS JUMP — max |z(ret)|=14.0 on 2024-12-16
# Saved: ./02-futures_prices/norgate_continuous\csv\FBTP.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FBTP.parquet
# ⚠ FBTP: Very late start — first date is 2024-01-22
# ⚠ FBTP: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FGBM.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FGBM.parquet
# ⚠ FGBM: Very late start — first date is 2024-01-22
# ⚠ FGBM: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FGBL.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FGBL.parquet
# ⚠ FGBL: Very late start — first date is 2024-01-22
# ⚠ FGBL: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FGBX.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FGBX.parquet
# ⚠ FGBX: Very late start — first date is 2024-01-22
# ⚠ FGBX: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FOAT.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FOAT.parquet
# ⚠ FOAT: Very late start — first date is 2024-01-22
# ⚠ FOAT: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FGBS.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FGBS.parquet
# ⚠ FGBS: Very late start — first date is 2024-01-22
# ⚠ FGBS: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\SJB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SJB.parquet
# ⚠ SJB: Very late start — first date is 2024-01-22
# ⚠ SJB: Short full history (<~5y) — only 526 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\LLG.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LLG.parquet
# ⚠ LLG: Very late start — first date is 2024-01-22
# ⚠ LLG: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\CRA.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\CRA.parquet
# ⚠ CRA: Very late start — first date is 2024-01-22
# ⚠ CRA: Short full history (<~5y) — only 503 trading days total.
# ⚠ CRA: SUSPICIOUS JUMP — max |z(ret)|=14.6 on 2024-12-17
# Saved: ./02-futures_prices/norgate_continuous\csv\ZB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ZB.parquet
# ⚠ ZB: Very late start — first date is 2024-01-22
# ⚠ ZB: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\TN.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\TN.parquet
# ⚠ TN: Very late start — first date is 2024-01-22
# ⚠ TN: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\UB.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\UB.parquet
# ⚠ UB: Very late start — first date is 2024-01-22
# ⚠ UB: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\HG.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\HG.parquet
# ⚠ HG: Very late start — first date is 2024-01-22
# ⚠ HG: Short full history (<~5y) — only 507 trading days total.
# ⚠ HG: SUSPICIOUS JUMP — max |z(ret)|=11.2 on 2025-07-31
# Saved: ./02-futures_prices/norgate_continuous\csv\GC.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\GC.parquet
# ⚠ GC: Very late start — first date is 2024-01-22
# ⚠ GC: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\PA.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\PA.parquet
# ⚠ PA: Very late start — first date is 2024-01-22
# ⚠ PA: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\PL.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\PL.parquet
# ⚠ PL: Very late start — first date is 2024-01-22
# ⚠ PL: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\SI.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SI.parquet
# ⚠ SI: Very late start — first date is 2024-01-22
# ⚠ SI: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\EUA.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\EUA.parquet
# ⚠ EUA: Very late start — first date is 2024-01-22
# ⚠ EUA: Short full history (<~5y) — only 517 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\GD.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\GD.parquet
# ⚠ GD: Very late start — first date is 2024-01-22
# ⚠ GD: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\YAP.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\YAP.parquet
# ⚠ YAP: Very late start — first date is 2024-01-22
# ⚠ YAP: Short full history (<~5y) — only 518 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FCE.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FCE.parquet
# ⚠ FCE: Very late start — first date is 2024-01-22
# ⚠ FCE: Short full history (<~5y) — only 516 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\VX.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\VX.parquet
# ⚠ VX: Very late start — first date is 2024-01-22
# ⚠ VX: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FDAX.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FDAX.parquet
# ⚠ FDAX: Very late start — first date is 2024-01-22
# ⚠ FDAX: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\YM.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\YM.parquet
# ⚠ YM: Very late start — first date is 2024-01-22
# ⚠ YM: Short full history (<~5y) — only 507 trading days total.
# ⚠ YM: SUSPICIOUS JUMP — max |z(ret)|=8.5 on 2025-04-09
# Saved: ./02-futures_prices/norgate_continuous\csv\NQ.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\NQ.parquet
# ⚠ NQ: Very late start — first date is 2024-01-22
# ⚠ NQ: Short full history (<~5y) — only 507 trading days total.
# ⚠ NQ: SUSPICIOUS JUMP — max |z(ret)|=8.9 on 2025-04-09
# Saved: ./02-futures_prices/norgate_continuous\csv\RTY.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\RTY.parquet
# ⚠ RTY: Very late start — first date is 2024-01-22
# ⚠ RTY: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\ES.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\ES.parquet
# ⚠ ES: Very late start — first date is 2024-01-22
# ⚠ ES: Short full history (<~5y) — only 507 trading days total.
# ⚠ ES: SUSPICIOUS JUMP — max |z(ret)|=9.3 on 2025-04-09
# Saved: ./02-futures_prices/norgate_continuous\csv\EMD.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\EMD.parquet
# ⚠ EMD: Very late start — first date is 2024-01-22
# ⚠ EMD: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FESX.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FESX.parquet
# ⚠ FESX: Very late start — first date is 2024-01-22
# ⚠ FESX: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\LFT.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\LFT.parquet
# ⚠ LFT: Very late start — first date is 2024-01-22
# ⚠ LFT: Short full history (<~5y) — only 511 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\SCN.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SCN.parquet
# ⚠ SCN: Very late start — first date is 2024-01-22
# ⚠ SCN: Short full history (<~5y) — only 526 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\HSI.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\HSI.parquet
# ⚠ HSI: Very late start — first date is 2024-01-22
# ⚠ HSI: Short full history (<~5y) — only 497 trading days total.
# ⚠ HSI: SUSPICIOUS JUMP — max |z(ret)|=8.5 on 2025-04-07
# Saved: ./02-futures_prices/norgate_continuous\csv\MHI.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\MHI.parquet
# ⚠ MHI: Very late start — first date is 2024-01-22
# ⚠ MHI: Short full history (<~5y) — only 497 trading days total.
# ⚠ MHI: SUSPICIOUS JUMP — max |z(ret)|=8.5 on 2025-04-07
# Saved: ./02-futures_prices/norgate_continuous\csv\KOS.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\KOS.parquet
# ⚠ KOS: Very late start — first date is 2024-01-22
# ⚠ KOS: Short full history (<~5y) — only 491 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\SSG.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SSG.parquet
# ⚠ SSG: Very late start — first date is 2024-01-22
# ⚠ SSG: Short full history (<~5y) — only 524 trading days total.
# ⚠ SSG: SUSPICIOUS JUMP — max |z(ret)|=9.3 on 2025-04-07
# Saved: ./02-futures_prices/norgate_continuous\csv\HTW.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\HTW.parquet
# ⚠ HTW: Very late start — first date is 2024-01-22
# ⚠ HTW: Short full history (<~5y) — only 497 trading days total.
# ⚠ HTW: SUSPICIOUS JUMP — max |z(ret)|=8.3 on 2025-04-10
# Saved: ./02-futures_prices/norgate_continuous\csv\MYM.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\MYM.parquet
# ⚠ MYM: Very late start — first date is 2024-01-22
# ⚠ MYM: Short full history (<~5y) — only 507 trading days total.
# ⚠ MYM: SUSPICIOUS JUMP — max |z(ret)|=8.5 on 2025-04-09
# Saved: ./02-futures_prices/norgate_continuous\csv\MNQ.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\MNQ.parquet
# ⚠ MNQ: Very late start — first date is 2024-01-22
# ⚠ MNQ: Short full history (<~5y) — only 507 trading days total.
# ⚠ MNQ: SUSPICIOUS JUMP — max |z(ret)|=8.9 on 2025-04-09
# Saved: ./02-futures_prices/norgate_continuous\csv\M2K.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\M2K.parquet
# ⚠ M2K: Very late start — first date is 2024-01-22
# ⚠ M2K: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\MES.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\MES.parquet
# ⚠ MES: Very late start — first date is 2024-01-22
# ⚠ MES: Short full history (<~5y) — only 507 trading days total.
# ⚠ MES: SUSPICIOUS JUMP — max |z(ret)|=9.2 on 2025-04-09
# Saved: ./02-futures_prices/norgate_continuous\csv\SNK.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SNK.parquet
# ⚠ SNK: Very late start — first date is 2024-01-22
# ⚠ SNK: Short full history (<~5y) — only 526 trading days total.
# ⚠ SNK: SUSPICIOUS JUMP — max |z(ret)|=8.7 on 2024-08-05
# Saved: ./02-futures_prices/norgate_continuous\csv\NKD.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\NKD.parquet
# ⚠ NKD: Very late start — first date is 2024-01-22
# ⚠ NKD: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\NIY.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\NIY.parquet
# ⚠ NIY: Very late start — first date is 2024-01-22
# ⚠ NIY: Short full history (<~5y) — only 507 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\SXF.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\SXF.parquet
# ⚠ SXF: Very late start — first date is 2024-01-22
# ⚠ SXF: Short full history (<~5y) — only 506 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FSMI.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FSMI.parquet
# ⚠ FSMI: Very late start — first date is 2024-01-22
# ⚠ FSMI: Short full history (<~5y) — only 503 trading days total.
# Saved: ./02-futures_prices/norgate_continuous\csv\FTDX.csv
# Saved: ./02-futures_prices/norgate_continuous\parquet\FTDX.parquet
# ⚠ FTDX: Very late start — first date is 2024-01-22
# ⚠ FTDX: Short full history (<~5y) — only 511 trading days total.
#
# ✔ Saved consolidated Parquet → ./02-futures_prices/norgate_continuous\norgate_continuous_all.parquet
# ✔ Saved consolidated CSV → ./02-futures_prices/norgate_continuous\norgate_continuous_all.csv
#
# ===============================================================================
# DONE — Norgate continuous futures history saved per instrument
# CSV folder:    ./02-futures_prices/norgate_continuous\csv
# Parquet folder: ./02-futures_prices/norgate_continuous\parquet
# ===============================================================================
