# %% [markdown]
# # Trend Following Backtest - With Micro/Mini Contract Support
#
# **Key Feature:** Generate signals from full-size contracts (better data/history), but size positions and calculate P&L using micro/mini specs for better granularity.
#
# **Data paths:**
# - Price data: `./02-futures_prices/norgate_continuous/csv/` or `/parquet/`
# - Margins: `margin_requirements.csv`
#
# **How it works:**
# - `signal_symbol`: Full-size contract used for price data and signal generation
# - `trade_symbol`: Micro/mini contract used for position sizing, margin, and P&L
# - If no micro exists, signal and trade symbol are the same

# %%
import pandas as pd
import numpy as np
import warnings
from typing import Dict, List, Tuple, Optional
from dataclasses import dataclass, field
from datetime import datetime
from pathlib import Path
import json
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (14, 6)

# Optional Norgate for metadata only
try:
    import norgatedata
    NORGATE_AVAILABLE = norgatedata.status()
except:
    NORGATE_AVAILABLE = False

print(f"✓ Imports successful | Norgate metadata: {NORGATE_AVAILABLE}")
# Out:
# ✓ Imports successful | Norgate metadata: True

# %%
# ==================== CONFIGURATION ====================
CONFIG = {
    'initial_capital': 400000,
    'commission_per_contract': 2.50,
    'fast_period': 50,
    'slow_period': 100,
    'vol_lookback': 60,
    'target_portfolio_vol': 0.20,
    'risk_per_trade': 0.01,
    'target_margin_usage': 0.25,
    'max_leverage': 3.0,
    'start_date': '2015-01-01',
    'end_date': None,
    
    # LOCAL DATA PATHS
    'csv_dir': './02-futures_prices/norgate_continuous/csv',
    'parquet_dir': './02-futures_prices/norgate_continuous/parquet',
    'prefer_parquet': True,
    'margin_file_path': './External_margin_file/margin_requirements.csv',
    'margin_column': 'Overnight Maintenance',
    
    # MICRO/MINI SETTINGS
    'use_micros': True,  # Set to False to use full-size only
}

print("Configuration loaded")
for k, v in CONFIG.items():
    print(f"  {k}: {v}")
# Out:
# Configuration loaded
#   initial_capital: 400000
#   commission_per_contract: 2.5
#   fast_period: 50
#   slow_period: 100
#   vol_lookback: 60
#   target_portfolio_vol: 0.2
#   risk_per_trade: 0.01
#   target_margin_usage: 0.25
#   max_leverage: 3.0
#   start_date: 2015-01-01
#   end_date: None
#   csv_dir: ./02-futures_prices/norgate_continuous/csv
#   parquet_dir: ./02-futures_prices/norgate_continuous/parquet
#   prefer_parquet: True
#   margin_file_path: ./External_margin_file/margin_requirements.csv
#   margin_column: Overnight Maintenance
#   use_micros: True

# %%
# ==================== MICRO/MINI CONTRACT MAPPING ====================
# Maps full-size signal symbol -> micro/mini trade symbol
# Only includes mappings where the micro/mini EXISTS and is commonly traded

MICRO_MINI_MAPPING = {
    # Equity Indices - Micros available in Norgate
    'ES': 'MES',    # E-mini S&P 500 -> Micro E-mini S&P 500
    'NQ': 'MNQ',    # E-mini Nasdaq -> Micro E-mini Nasdaq
    'RTY': 'M2K',   # E-mini Russell 2000 -> Micro E-mini Russell
    'YM': 'MYM',    # E-mini Dow -> Micro E-mini Dow
    
    # Crypto - Micros available in Norgate
    'BTC': 'MBT',   # Bitcoin -> Micro Bitcoin
    'ETH': 'MET',   # Ether -> Micro Ether
}

# Additional mappings for contracts where micro EXISTS at broker but NOT in Norgate
# These would use full-size data for signals but micro specs for sizing
# You'd trade the micro in live trading
BROKER_ONLY_MICROS = {
    # Currencies - Micros exist at broker, not in Norgate
    '6A': 'M6A',    # Australian Dollar -> Micro AUD
    '6B': 'M6B',    # British Pound -> Micro GBP
    '6C': 'MCD',    # Canadian Dollar -> Micro CAD
    '6E': 'M6E',    # Euro FX -> Micro EUR
    '6J': 'MJY',    # Japanese Yen -> Micro JPY
    '6S': 'MSF',    # Swiss Franc -> Micro CHF
    
    # Energy - Micros exist at broker, not in Norgate
    'CL': 'MCL',    # Crude Oil -> Micro WTI
    'NG': 'MNG',    # Natural Gas -> Micro Henry Hub
    'RB': 'MRB',    # RBOB Gasoline -> Micro RBOB
    'HO': 'MHO',    # Heating Oil -> Micro Heating Oil
    
    # Metals - Micros exist at broker, not in Norgate
    'GC': 'MGC',    # Gold -> Micro Gold
    'SI': 'SIL',    # Silver -> Micro Silver (1000 oz)
    'HG': 'MHG',    # Copper -> Micro Copper
    
    # Agriculture - Micros exist at broker, not in Norgate
    'ZC': 'MZC',    # Corn -> Micro Corn
    'ZW': 'MZW',    # Wheat -> Micro Wheat
    'ZS': 'MZS',    # Soybeans -> Micro Soybeans
    'ZM': 'MZM',    # Soybean Meal -> Micro Soybean Meal
    'ZL': 'MZL',    # Soybean Oil -> Micro Soybean Oil
    
    # Volatility
    'VX': 'VXM',    # VIX -> Mini VIX
}

print(f"✓ Micro mappings defined")
print(f"  Norgate micros: {len(MICRO_MINI_MAPPING)}")
print(f"  Broker-only micros: {len(BROKER_ONLY_MICROS)}")
# Out:
# ✓ Micro mappings defined
#   Norgate micros: 6
#   Broker-only micros: 19

# %%
# ==================== TRADE CONTRACT SPECIFICATIONS ====================
# Point values and other specs for TRADE symbols (micros/minis)
# These override the signal symbol specs when sizing positions

TRADE_CONTRACT_SPECS = {
    # Micro Equity Indices (in Norgate)
    'MES': {'point_value': 5, 'tick_size': 0.25, 'tick_value': 1.25},
    'MNQ': {'point_value': 2, 'tick_size': 0.25, 'tick_value': 0.50},
    'M2K': {'point_value': 5, 'tick_size': 0.10, 'tick_value': 0.50},
    'MYM': {'point_value': 0.5, 'tick_size': 1.0, 'tick_value': 0.50},
    
    # Micro Crypto (in Norgate)
    'MBT': {'point_value': 0.1, 'tick_size': 5, 'tick_value': 0.50},
    'MET': {'point_value': 0.1, 'tick_size': 0.05, 'tick_value': 0.005},
    
    # Micro Currencies (broker only) - 1/10th of full-size
    'M6A': {'point_value': 10000, 'tick_size': 0.0001, 'tick_value': 1.00},
    'M6B': {'point_value': 6250, 'tick_size': 0.0001, 'tick_value': 0.625},
    'MCD': {'point_value': 10000, 'tick_size': 0.00005, 'tick_value': 0.50},
    'M6E': {'point_value': 12500, 'tick_size': 0.0001, 'tick_value': 1.25},
    'MJY': {'point_value': 12500, 'tick_size': 0.000001, 'tick_value': 0.0125},
    'MSF': {'point_value': 12500, 'tick_size': 0.0001, 'tick_value': 1.25},
    
    # Micro Energy (broker only) - 1/10th of full-size
    'MCL': {'point_value': 100, 'tick_size': 0.01, 'tick_value': 1.00},
    'MNG': {'point_value': 1000, 'tick_size': 0.001, 'tick_value': 1.00},
    'MRB': {'point_value': 4200, 'tick_size': 0.0001, 'tick_value': 0.42},
    'MHO': {'point_value': 4200, 'tick_size': 0.0001, 'tick_value': 0.42},
    
    # Micro Metals (broker only)
    'MGC': {'point_value': 10, 'tick_size': 0.10, 'tick_value': 1.00},
    'SIL': {'point_value': 1000, 'tick_size': 0.005, 'tick_value': 5.00},
    'MHG': {'point_value': 2500, 'tick_size': 0.0005, 'tick_value': 1.25},
    
    # Micro Agriculture (broker only) - 1/10th of full-size
    'MZC': {'point_value': 5, 'tick_size': 0.125, 'tick_value': 0.625},
    'MZW': {'point_value': 5, 'tick_size': 0.125, 'tick_value': 0.625},
    'MZS': {'point_value': 5, 'tick_size': 0.125, 'tick_value': 0.625},
    'MZM': {'point_value': 10, 'tick_size': 0.10, 'tick_value': 1.00},
    'MZL': {'point_value': 60, 'tick_size': 0.01, 'tick_value': 0.60},
    
    # Mini VIX (broker only) - 1/10th of full-size
    'VXM': {'point_value': 100, 'tick_size': 0.05, 'tick_value': 5.00},
}

print(f"✓ Trade contract specs defined for {len(TRADE_CONTRACT_SPECS)} micro/mini contracts")
# Out:
# ✓ Trade contract specs defined for 25 micro/mini contracts

# %%
# ==================== DATA CLASSES ====================
@dataclass
class FuturesContract:
    """Futures contract with separate signal and trade specifications"""
    # Identifiers
    signal_symbol: str          # Symbol for price data / signals (e.g., 'ES')
    trade_symbol: str           # Symbol actually traded (e.g., 'MES')
    name: str
    sector: str
    
    # Signal contract specs (for volatility calculation)
    signal_point_value: float
    
    # Trade contract specs (for position sizing and P&L)
    trade_point_value: float
    trade_tick_size: float
    trade_margin: float
    margin_source: str = 'unknown'
    
    # Computed
    granularity_factor: float = field(init=False)
    is_micro: bool = field(init=False)
    
    def __post_init__(self):
        self.granularity_factor = self.signal_point_value / self.trade_point_value if self.trade_point_value > 0 else 1
        self.is_micro = self.signal_symbol != self.trade_symbol

print("✓ Data classes defined")
# Out:
# ✓ Data classes defined

# %%
# ==================== FULL-SIZE CONTRACT SPECS (for signals) ====================
SIGNAL_CONTRACT_SPECS = {
    # Equity Indices
    'ES': {'point_value': 50, 'sector': 'Stock Index'},
    'NQ': {'point_value': 20, 'sector': 'Stock Index'},
    'RTY': {'point_value': 50, 'sector': 'Stock Index'},
    'YM': {'point_value': 5, 'sector': 'Stock Index'},
    'EMD': {'point_value': 100, 'sector': 'Stock Index'},
    'FESX': {'point_value': 10, 'sector': 'Stock Index'},
    'FDAX': {'point_value': 25, 'sector': 'Stock Index'},
    'NKD': {'point_value': 5, 'sector': 'Stock Index'},
    'NIY': {'point_value': 500, 'sector': 'Stock Index'},
    
    # Interest Rates
    'ZB': {'point_value': 1000, 'sector': 'Interest Rate'},
    'ZN': {'point_value': 1000, 'sector': 'Interest Rate'},
    'ZF': {'point_value': 1000, 'sector': 'Interest Rate'},
    'ZT': {'point_value': 2000, 'sector': 'Interest Rate'},
    'FGBL': {'point_value': 1000, 'sector': 'Interest Rate'},
    'FGBM': {'point_value': 1000, 'sector': 'Interest Rate'},
    'FGBS': {'point_value': 1000, 'sector': 'Interest Rate'},
    
    # Energy
    'CL': {'point_value': 1000, 'sector': 'Energy'},
    'NG': {'point_value': 10000, 'sector': 'Energy'},
    'HO': {'point_value': 42000, 'sector': 'Energy'},
    'RB': {'point_value': 42000, 'sector': 'Energy'},
    'BRN': {'point_value': 1000, 'sector': 'Energy'},
    
    # Metals
    'GC': {'point_value': 100, 'sector': 'Metals'},
    'SI': {'point_value': 5000, 'sector': 'Metals'},
    'HG': {'point_value': 25000, 'sector': 'Metals'},
    'PL': {'point_value': 50, 'sector': 'Metals'},
    'PA': {'point_value': 100, 'sector': 'Metals'},
    
    # Agriculture
    'ZC': {'point_value': 50, 'sector': 'Agriculture'},
    'ZS': {'point_value': 50, 'sector': 'Agriculture'},
    'ZW': {'point_value': 50, 'sector': 'Agriculture'},
    'ZM': {'point_value': 100, 'sector': 'Agriculture'},
    'ZL': {'point_value': 600, 'sector': 'Agriculture'},
    'CT': {'point_value': 500, 'sector': 'Agriculture'},
    'KC': {'point_value': 375, 'sector': 'Agriculture'},
    'SB': {'point_value': 1120, 'sector': 'Agriculture'},
    'CC': {'point_value': 10, 'sector': 'Agriculture'},
    
    # Currencies
    '6E': {'point_value': 125000, 'sector': 'Currency'},
    '6J': {'point_value': 125000, 'sector': 'Currency'},
    '6B': {'point_value': 62500, 'sector': 'Currency'},
    '6A': {'point_value': 100000, 'sector': 'Currency'},
    '6C': {'point_value': 100000, 'sector': 'Currency'},
    '6S': {'point_value': 125000, 'sector': 'Currency'},
    'DX': {'point_value': 1000, 'sector': 'Currency'},
    
    # Crypto
    'BTC': {'point_value': 5, 'sector': 'Crypto'},
    'ETH': {'point_value': 50, 'sector': 'Crypto'},
    
    # Volatility
    'VX': {'point_value': 1000, 'sector': 'Volatility'},
}

print(f"✓ Signal contract specs defined for {len(SIGNAL_CONTRACT_SPECS)} contracts")
# Out:
# ✓ Signal contract specs defined for 45 contracts

# %%
# ==================== LOCAL DATA LOADING ====================
def load_local_price_data(symbol: str) -> Optional[pd.DataFrame]:
    """Load price data from local CSV/Parquet files."""
    clean_symbol = symbol.strip().upper().lstrip('&')
    
    if CONFIG['prefer_parquet']:
        paths = [
            (CONFIG['parquet_dir'], f"{clean_symbol}.parquet", 'parquet'),
            (CONFIG['csv_dir'], f"{clean_symbol}.csv", 'csv'),
        ]
    else:
        paths = [
            (CONFIG['csv_dir'], f"{clean_symbol}.csv", 'csv'),
            (CONFIG['parquet_dir'], f"{clean_symbol}.parquet", 'parquet'),
        ]
    
    for directory, filename, fmt in paths:
        filepath = Path(directory) / filename
        if filepath.exists():
            try:
                if fmt == 'parquet':
                    df = pd.read_parquet(filepath)
                else:
                    df = pd.read_csv(filepath)
                return _standardize_df(df)
            except Exception as e:
                continue
    return None

def _standardize_df(df: pd.DataFrame) -> pd.DataFrame:
    """Standardize column names: lowercase -> Title Case"""
    if 'date' in df.columns:
        df = df.set_index('date')
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index)
    df = df.sort_index()
    
    col_map = {'open': 'Open', 'high': 'High', 'low': 'Low', 
               'close': 'Close', 'volume': 'Volume', 'settle': 'Close'}
    df.columns = [col_map.get(c.lower().strip(), c) for c in df.columns]
    return df

def get_available_symbols() -> List[str]:
    """Get symbols with local data."""
    symbols = set()
    for d in [CONFIG['csv_dir'], CONFIG['parquet_dir']]:
        p = Path(d)
        if p.exists():
            for f in p.glob('*.*'):
                if f.suffix in ['.csv', '.parquet']:
                    symbols.add(f.stem.upper())
    return sorted(symbols)

# Test
available = get_available_symbols()
print(f"✓ Found {len(available)} symbols with local data")
if available:
    print(f"  First 10: {available[:10]}")
# Out:
# ✓ Found 105 symbols with local data
#   First 10: ['6A', '6B', '6C', '6E', '6J', '6M', '6N', '6S', 'AFB', 'AWM']

# %%
# ==================== MARGIN LOADING ====================
def load_margin_lookup() -> Dict:
    """Load margin requirements from CSV - indexed by Trading Class."""
    try:
        df = pd.read_csv(CONFIG['margin_file_path'])
        print(f"✓ Loaded {len(df)} margin records")
    except FileNotFoundError:
        print(f"⚠ Margin file not found")
        return {}
    
    lookup = {}
    if 'Currency' in df.columns:
        df = df.sort_values(by='Currency', key=lambda x: x != 'USD')
    
    for _, row in df.iterrows():
        sym = str(row.get('Trading Class', '')).strip().upper()
        if not sym or sym in lookup:
            continue
        try:
            margin = float(row[CONFIG['margin_column']])
            if pd.notna(margin) and margin > 0:
                lookup[sym] = margin
        except:
            continue
    print(f"✓ {len(lookup)} unique margin entries")
    return lookup

margin_lookup = load_margin_lookup()
# Out:
# ✓ Loaded 355 margin records
# ✓ 349 unique margin entries

# %%
# ==================== BUILD INSTRUMENT UNIVERSE ====================
def get_trade_symbol(signal_symbol: str, use_micros: bool = True) -> str:
    """Get the trade symbol for a given signal symbol."""
    if not use_micros:
        return signal_symbol
    
    # Check Norgate micros first (we have data for these)
    if signal_symbol in MICRO_MINI_MAPPING:
        return MICRO_MINI_MAPPING[signal_symbol]
    
    # Check broker-only micros (we use full-size data but micro specs)
    if signal_symbol in BROKER_ONLY_MICROS:
        return BROKER_ONLY_MICROS[signal_symbol]
    
    return signal_symbol


def get_margin_for_symbol(symbol: str, margin_lookup: Dict) -> Tuple[float, str]:
    """Get margin for symbol from lookup."""
    if symbol in margin_lookup:
        return margin_lookup[symbol], 'spreadsheet'
    
    # Try Norgate if available
    if NORGATE_AVAILABLE:
        try:
            m = norgatedata.margin(f"&{symbol}")
            if m and m > 0:
                return m, 'norgate'
        except:
            pass
    
    return 5000, 'default'


def build_universe(signal_symbols: List[str], 
                   use_micros: bool = True,
                   max_margin: float = None) -> List[FuturesContract]:
    """
    Build instrument universe with signal/trade symbol mapping.
    
    Parameters:
    -----------
    signal_symbols : List[str]
        List of full-size symbols to use for signals
    use_micros : bool
        If True, use micro/mini contracts for trading where available
    max_margin : float
        Maximum margin per contract (filters out expensive contracts)
    """
    available_data = set(get_available_symbols())
    instruments = []
    skipped = []
    
    print(f"Building universe from {len(signal_symbols)} signal symbols...")
    print(f"Use micros: {use_micros}")
    print("=" * 70)
    
    for signal_sym in signal_symbols:
        signal_sym = signal_sym.strip().upper()
        
        # Check we have data for the signal symbol
        if signal_sym not in available_data:
            skipped.append(f"{signal_sym} (no signal data)")
            continue
        
        # Get trade symbol
        trade_sym = get_trade_symbol(signal_sym, use_micros)
        
        # Get signal specs
        if signal_sym in SIGNAL_CONTRACT_SPECS:
            signal_specs = SIGNAL_CONTRACT_SPECS[signal_sym]
        elif NORGATE_AVAILABLE:
            try:
                pv = norgatedata.point_value(f"&{signal_sym}")
                sector = norgatedata.classification(f"&{signal_sym}", 
                    'NorgateDataFuturesClassification', 'Name') or 'Unknown'
                signal_specs = {'point_value': pv or 1000, 'sector': sector}
            except:
                signal_specs = {'point_value': 1000, 'sector': 'Unknown'}
        else:
            skipped.append(f"{signal_sym} (no specs)")
            continue
        
        # Get trade specs
        if trade_sym in TRADE_CONTRACT_SPECS:
            trade_pv = TRADE_CONTRACT_SPECS[trade_sym]['point_value']
            trade_tick = TRADE_CONTRACT_SPECS[trade_sym]['tick_size']
        else:
            # Same as signal (full-size)
            trade_pv = signal_specs['point_value']
            trade_tick = 0.01
        
        # Get margin for TRADE symbol
        margin, margin_src = get_margin_for_symbol(trade_sym, margin_lookup)
        
        # Filter by max margin
        if max_margin and margin > max_margin:
            skipped.append(f"{signal_sym} (margin ${margin:,.0f})")
            continue
        
        # Get name
        if NORGATE_AVAILABLE:
            try:
                name = norgatedata.futures_market_name(signal_sym) or signal_sym
            except:
                name = signal_sym
        else:
            name = signal_sym
        
        instruments.append(FuturesContract(
            signal_symbol=signal_sym,
            trade_symbol=trade_sym,
            name=name,
            sector=signal_specs['sector'],
            signal_point_value=signal_specs['point_value'],
            trade_point_value=trade_pv,
            trade_tick_size=trade_tick,
            trade_margin=margin,
            margin_source=margin_src,
        ))
    
    print(f"\n✓ Built universe with {len(instruments)} instruments")
    micros = sum(1 for i in instruments if i.is_micro)
    print(f"  Using micros/minis: {micros}")
    print(f"  Using full-size: {len(instruments) - micros}")
    
    if skipped:
        print(f"\n⚠ Skipped {len(skipped)}:")
        for s in skipped[:10]:
            print(f"   - {s}")
        if len(skipped) > 10:
            print(f"   ... and {len(skipped) - 10} more")
    
    return instruments

# %%
# ==================== SELECTED SYMBOLS ====================
SELECTED_SIGNALS = [
    # Equity Indices
    'ES', 'NQ', 'RTY', 'YM', 'EMD',
    'FESX', 'NKD',
    
    # Interest Rates
    'ZB', 'ZN', 'ZF', 'ZT',
    'FGBL', 'FGBM', 'FGBS',
    
    # Energy
    'CL', 'NG', 'RB', 'BRN',
    
    # Metals
    'GC', 'HG', 'PL',
    
    # Agriculture
    'ZC', 'ZS', 'ZW', 'ZM', 'ZL',
    'CT', 'SB', 'CC',
    
    # Currencies
    '6E', '6J', '6B', '6A', '6C', '6S', 'DX',
    
    # Volatility
    'VX',
]

# Build universe
instruments = build_universe(
    SELECTED_SIGNALS,
    use_micros=CONFIG['use_micros'],
    max_margin=CONFIG['initial_capital'] * 0.05
)
# Out:
# Building universe from 37 signal symbols...
# Use micros: True
# ======================================================================
#
# ✓ Built universe with 36 instruments
#   Using micros/minis: 21
#   Using full-size: 15
#
# ⚠ Skipped 1:
#    - EMD (margin $23,038)

# %%
# ==================== DISPLAY UNIVERSE WITH MAPPING ====================
print("\n" + "=" * 100)
print("INSTRUMENT UNIVERSE - SIGNAL/TRADE MAPPING")
print("=" * 100)
print(f"{'Signal':<8} {'Trade':<8} {'Name':<25} {'Sector':<15} {'Sig PV':>10} {'Trade PV':>10} {'Margin':>10} {'Granul':>8}")
print("-" * 100)

for inst in sorted(instruments, key=lambda x: (x.sector, x.signal_symbol)):
    micro_flag = "*" if inst.is_micro else " "
    print(f"{inst.signal_symbol:<8} {inst.trade_symbol:<7}{micro_flag} {inst.name[:24]:<25} {inst.sector:<15} "
          f"${inst.signal_point_value:>8,.0f} ${inst.trade_point_value:>8,.1f} ${inst.trade_margin:>8,.0f} "
          f"{inst.granularity_factor:>7.1f}x")

print("-" * 100)
print("* = Using micro/mini for trading")
print(f"\nGranularity factor = Signal PV / Trade PV (higher = finer position sizing)")
# Out:
# ====================================================================================================
# INSTRUMENT UNIVERSE - SIGNAL/TRADE MAPPING
# ====================================================================================================
# Signal   Trade    Name                      Sector              Sig PV   Trade PV     Margin   Granul
# ----------------------------------------------------------------------------------------------------
# CC       CC       Cocoa                     Agriculture     $      10 $    10.0 $   9,736     1.0x
# CT       CT       Cotton No. 2              Agriculture     $     500 $   500.0 $   1,467     1.0x
# SB       SB       Sugar No. 11              Agriculture     $   1,120 $ 1,120.0 $   1,451     1.0x
# ZC       MZC    * Corn                      Agriculture     $      50 $     5.0 $     142    10.0x
# ZL       MZL    * Soybean Oil               Agriculture     $     600 $    60.0 $     292    10.0x
# ZM       MZM    * Soybean Meal              Agriculture     $     100 $    10.0 $     244    10.0x
# ZS       MZS    * Soybean                   Agriculture     $      50 $     5.0 $     322    10.0x
# ZW       MZW    * Chicago SRW Wheat         Agriculture     $      50 $     5.0 $     176    10.0x
# 6A       M6A    * Australian Dollar         Currency        $ 100,000 $10,000.0 $     194    10.0x
# 6B       M6B    * British Pound             Currency        $  62,500 $ 6,250.0 $     209    10.0x
# 6C       MCD    * Canadian Dollar           Currency        $ 100,000 $10,000.0 $     122    10.0x
# 6E       M6E    * Euro FX                   Currency        $ 125,000 $12,500.0 $     282    10.0x
# 6J       MJY    * Japanese Yen              Currency        $ 125,000 $12,500.0 $     280    10.0x
# 6S       MSF    * Swiss Franc               Currency        $ 125,000 $12,500.0 $     472    10.0x
# DX       DX       US Dollar Index           Currency        $   1,000 $ 1,000.0 $   1,974     1.0x
# BRN      BRN      Brent Crude Oil           Energy          $   1,000 $ 1,000.0 $   4,350     1.0x
# CL       MCL    * Crude Oil                 Energy          $   1,000 $   100.0 $   1,300    10.0x
# NG       MNG    * Henry Hub Natural Gas     Energy          $  10,000 $ 1,000.0 $     857    10.0x
# RB       MRB    * RBOB Gasoline             Energy          $  42,000 $ 4,200.0 $   1,764    10.0x
# FGBL     FGBL     Euro-Bund                 Interest Rate   $   1,000 $ 1,000.0 $   1,957     1.0x
# FGBM     FGBM     Euro-Bobl                 Interest Rate   $   1,000 $ 1,000.0 $   1,060     1.0x
# FGBS     FGBS     Euro-Schatz               Interest Rate   $   1,000 $ 1,000.0 $     390     1.0x
# ZB       ZB       U.S. T-Bond               Interest Rate   $   1,000 $ 1,000.0 $   3,700     1.0x
# ZF       ZF       5-Year U.S. T-Note        Interest Rate   $   1,000 $ 1,000.0 $   1,250     1.0x
# ZN       ZN       10-Year U.S. T-Note       Interest Rate   $   1,000 $ 1,000.0 $   1,875     1.0x
# ZT       ZT       2-Year U.S. T-Note        Interest Rate   $   2,000 $ 2,000.0 $   1,200     1.0x
# GC       MGC    * Gold                      Metals          $     100 $    10.0 $   3,270    10.0x
# HG       MHG    * Copper                    Metals          $  25,000 $ 2,500.0 $   1,634    10.0x
# PL       PL       Platinum                  Metals          $      50 $    50.0 $  19,068     1.0x
# ES       MES    * E-mini S&P 500            Stock Index     $      50 $     5.0 $   2,247    10.0x
# FESX     FESX     EURO STOXX 50             Stock Index     $      10 $    10.0 $   4,096     1.0x
# NKD      NKD      Nikkei 225 Dollar         Stock Index     $       5 $     5.0 $  18,239     1.0x
# NQ       MNQ    * E-mini Nasdaq-100         Stock Index     $      20 $     2.0 $   3,369    10.0x
# RTY      M2K    * E-mini Russell 2000       Stock Index     $      50 $     5.0 $     955    10.0x
# YM       MYM    * E-mini Dow ($5)           Stock Index     $       5 $     0.5 $   1,426    10.0x
# VX       VXM    * CBOE Volatility Index     Volatility      $   1,000 $   100.0 $     835    10.0x
# ----------------------------------------------------------------------------------------------------
# * = Using micro/mini for trading
#
# Granularity factor = Signal PV / Trade PV (higher = finer position sizing)

# %%
# ==================== STRATEGY CLASSES ====================
class TrendFollowingStrategy:
    def __init__(self, fast=50, slow=100, vol_lb=60):
        self.fast_period, self.slow_period, self.vol_lookback = fast, slow, vol_lb
    
    def calculate_signals(self, prices: pd.Series) -> pd.Series:
        fast = prices.rolling(self.fast_period).mean()
        slow = prices.rolling(self.slow_period).mean()
        sig = pd.Series(0, index=prices.index)
        sig[fast > slow] = 1
        sig[fast < slow] = -1
        return sig
    
    def calculate_volatility(self, prices: pd.Series) -> pd.Series:
        return prices.pct_change().rolling(self.vol_lookback).std() * np.sqrt(252)


class PositionSizer:
    def __init__(self, account, target_vol=0.20, risk=0.01, max_lev=3.0):
        self.account_size = account
        self.risk_per_trade = risk
        self.max_leverage = max_lev
    
    def calculate_position_size(self, signal, inst: FuturesContract, price, vol, _) -> int:
        """
        Calculate position size using TRADE contract specs.
        
        Note: volatility is calculated from signal prices, but we size
        using trade_point_value for the actual contracts we'll hold.
        """
        if signal == 0 or np.isnan(vol) or vol == 0:
            return 0
        
        # Dollar volatility per TRADE contract
        dollar_vol = price * inst.trade_point_value * vol
        
        # Position size based on risk
        risk_capital = self.account_size * self.risk_per_trade
        contracts = int(np.sign(signal) * risk_capital / dollar_vol)
        
        # Leverage limit using trade specs
        notional = abs(contracts) * price * inst.trade_point_value
        if notional > self.account_size * self.max_leverage:
            contracts = int(np.sign(contracts) * self.account_size * self.max_leverage / 
                          (price * inst.trade_point_value))
        
        return contracts


class PortfolioManager:
    def __init__(self, account, target_margin=0.25):
        self.account_size = account
        self.target_margin_usage = target_margin
    
    def update_positions(self, positions: Dict[str, Tuple[int, FuturesContract]]):
        """Apply margin constraints using TRADE margin."""
        total_margin = sum(abs(c) * inst.trade_margin for c, inst in positions.values())
        max_margin = self.account_size * self.target_margin_usage
        
        if total_margin > max_margin:
            scale = max_margin / total_margin
            return {s: (int(c * scale), inst) for s, (c, inst) in positions.items()}
        return positions
    
    def get_portfolio_statistics(self, positions: Dict[str, Tuple[int, FuturesContract, float]]) -> Dict:
        total_margin = sum(abs(c) * inst.trade_margin for c, inst, _ in positions.values())
        return {
            'margin_utilization': total_margin / self.account_size if self.account_size > 0 else 0,
            'num_positions': len([c for c, _, _ in positions.values() if c != 0])
        }

print("✓ Strategy classes defined")
# Out:
# ✓ Strategy classes defined

# %%
# ==================== TRADE LOGGING & REPORTING ====================
from dataclasses import dataclass, field
from typing import List, Dict, Tuple, Optional
import pandas as pd
import numpy as np
from datetime import datetime


@dataclass
class TradeRecord:
    """Record of a single trade execution."""
    date: pd.Timestamp
    signal_symbol: str
    trade_symbol: str
    side: str  # 'BUY' or 'SELL'
    contracts: int
    price: float
    point_value: float
    notional_value: float
    margin_required: float
    commission: float
    signal_value: int  # -1, 0, or 1
    volatility: float
    reason: str  # 'ENTRY', 'EXIT', 'REBALANCE', 'MARGIN_SCALE'


@dataclass
class PortfolioSnapshot:
    """Snapshot of portfolio state after a trade."""
    date: pd.Timestamp
    cash: float
    equity: float
    total_margin: float
    margin_utilization: float
    num_positions: int
    positions: Dict[str, dict]  # symbol -> {contracts, price, notional, margin, unrealized_pnl}
    daily_pnl: float
    cumulative_pnl: float


class TradeLogger:
    """Logs all trades and portfolio snapshots during backtest."""
    
    def __init__(self, initial_capital: float):
        self.initial_capital = initial_capital
        self.trades: List[TradeRecord] = []
        self.snapshots: List[PortfolioSnapshot] = []
        self.cumulative_pnl = 0.0
    
    def log_trade(self, trade: TradeRecord):
        """Log a single trade."""
        self.trades.append(trade)
    
    def log_snapshot(self, snapshot: PortfolioSnapshot):
        """Log a portfolio snapshot."""
        self.snapshots.append(snapshot)
    
    def get_trades_df(self) -> pd.DataFrame:
        """Return trades as a DataFrame."""
        if not self.trades:
            return pd.DataFrame()
        
        records = []
        for t in self.trades:
            records.append({
                'date': t.date,
                'signal_symbol': t.signal_symbol,
                'trade_symbol': t.trade_symbol,
                'side': t.side,
                'contracts': t.contracts,
                'price': t.price,
                'point_value': t.point_value,
                'notional_value': t.notional_value,
                'margin_required': t.margin_required,
                'commission': t.commission,
                'signal': t.signal_value,
                'volatility': t.volatility,
                'reason': t.reason,
            })
        
        return pd.DataFrame(records)
    
    def get_snapshots_df(self) -> pd.DataFrame:
        """Return snapshots as a DataFrame."""
        if not self.snapshots:
            return pd.DataFrame()
        
        records = []
        for s in self.snapshots:
            rec = {
                'date': s.date,
                'cash': s.cash,
                'equity': s.equity,
                'total_margin': s.total_margin,
                'margin_utilization': s.margin_utilization,
                'num_positions': s.num_positions,
                'daily_pnl': s.daily_pnl,
                'cumulative_pnl': s.cumulative_pnl,
            }
            # Add position details as separate columns
            for sym, pos in s.positions.items():
                rec[f'{sym}_contracts'] = pos.get('contracts', 0)
                rec[f'{sym}_price'] = pos.get('price', 0)
                rec[f'{sym}_notional'] = pos.get('notional', 0)
                rec[f'{sym}_unrealized_pnl'] = pos.get('unrealized_pnl', 0)
            records.append(rec)
        
        return pd.DataFrame(records)


class MicroAwareBacktestEngineWithLogging(MicroAwareBacktestEngine):
    """
    Extended backtest engine with detailed trade logging.
    """
    
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.trade_logger = TradeLogger(self.initial_capital)
        self.entry_prices = {}  # Track entry prices for P&L calculation
    
    def run_backtest(self, price_data: Dict[str, pd.DataFrame]) -> pd.DataFrame:
        """Run backtest with detailed trade logging."""
        # Common dates
        all_dates = None
        for df in price_data.values():
            all_dates = set(df.index) if all_dates is None else all_dates & set(df.index)
        dates = sorted(all_dates)
        
        print(f"Backtest: {dates[0].date()} to {dates[-1].date()} ({len(dates)} days)")
        
        positions = {s: 0 for s in self.instruments}
        equity = self.initial_capital
        cash = self.initial_capital
        results = []
        
        for i, date in enumerate(dates):
            if i < self.strategy.slow_period:
                results.append({'date': date, 'equity': equity, 'daily_return': 0,
                               'num_positions': 0, 'margin_usage': 0})
                continue
            
            # Calculate signals and target positions
            new_pos = {}
            signals_data = {}
            
            for signal_sym, inst in self.instruments.items():
                if signal_sym not in price_data or date not in price_data[signal_sym].index:
                    continue
                
                df = price_data[signal_sym]
                hist = df.loc[df.index <= date, 'Close']
                price = hist.iloc[-1]
                
                # Signal from full-size data
                sig = self.strategy.calculate_signals(hist).iloc[-1]
                vol = self.strategy.calculate_volatility(hist).iloc[-1]
                
                # Size using TRADE specs (micro/mini)
                contracts = self.position_sizer.calculate_position_size(
                    sig, inst, price, vol, positions)
                
                new_pos[signal_sym] = (contracts, inst, price)
                signals_data[signal_sym] = {'signal': sig, 'vol': vol, 'price': price}
            
            # Apply margin constraints using TRADE margin
            managed = self.portfolio_manager.update_positions(
                {s: (c, inst) for s, (c, inst, _) in new_pos.items()})
            
            # Track if margin scaling was applied
            margin_scaled = any(
                managed.get(s, (0, None))[0] != new_pos.get(s, (0, None, None))[0]
                for s in new_pos
            )
            
            # Log trades for position changes
            daily_commission = 0
            for signal_sym in self.instruments:
                if signal_sym in managed and signal_sym in price_data:
                    if date in price_data[signal_sym].index:
                        new_c = managed[signal_sym][0]
                        old_c = positions[signal_sym]
                        
                        if new_c != old_c:
                            inst = self.instruments[signal_sym]
                            price = signals_data.get(signal_sym, {}).get('price', 0)
                            sig = signals_data.get(signal_sym, {}).get('signal', 0)
                            vol = signals_data.get(signal_sym, {}).get('vol', 0)
                            
                            trade_contracts = abs(new_c - old_c)
                            commission = trade_contracts * self.commission
                            daily_commission += commission
                            
                            # Determine trade side and reason
                            if new_c > old_c:
                                side = 'BUY'
                                if old_c == 0:
                                    reason = 'ENTRY_LONG'
                                elif old_c < 0:
                                    reason = 'COVER_SHORT' if new_c >= 0 else 'REDUCE_SHORT'
                                else:
                                    reason = 'ADD_LONG'
                            else:
                                side = 'SELL'
                                if old_c == 0:
                                    reason = 'ENTRY_SHORT'
                                elif old_c > 0:
                                    reason = 'EXIT_LONG' if new_c <= 0 else 'REDUCE_LONG'
                                else:
                                    reason = 'ADD_SHORT'
                            
                            if margin_scaled and reason not in ['ENTRY_LONG', 'ENTRY_SHORT']:
                                reason += '_MARGIN_SCALED'
                            
                            # Log the trade
                            trade = TradeRecord(
                                date=date,
                                signal_symbol=signal_sym,
                                trade_symbol=inst.trade_symbol,
                                side=side,
                                contracts=trade_contracts,
                                price=price,
                                point_value=inst.trade_point_value,
                                notional_value=trade_contracts * price * inst.trade_point_value,
                                margin_required=trade_contracts * inst.trade_margin,
                                commission=commission,
                                signal_value=int(sig),
                                volatility=vol,
                                reason=reason,
                            )
                            self.trade_logger.log_trade(trade)
                            
                            # Update entry price tracking
                            if new_c != 0:
                                if old_c == 0 or np.sign(new_c) != np.sign(old_c):
                                    self.entry_prices[signal_sym] = price
                            else:
                                self.entry_prices.pop(signal_sym, None)
            
            # Calculate P&L using TRADE point value
            daily_pnl = 0
            if i > 0:
                prev = dates[i-1]
                for signal_sym, c in positions.items():
                    if c != 0 and signal_sym in price_data:
                        df = price_data[signal_sym]
                        if date in df.index and prev in df.index:
                            price_change = df.loc[date, 'Close'] - df.loc[prev, 'Close']
                            inst = self.instruments[signal_sym]
                            daily_pnl += c * price_change * inst.trade_point_value
            
            equity += daily_pnl - daily_commission
            cash = equity - sum(
                abs(positions.get(s, 0)) * self.instruments[s].trade_margin
                for s in self.instruments
            )
            
            # Update positions
            for s, (c, _) in managed.items():
                positions[s] = c
            
            # Calculate portfolio statistics
            pos_data = {}
            for s in positions:
                if positions[s] != 0:
                    inst = self.instruments[s]
                    current_price = price_data[s].loc[date, 'Close'] if s in price_data and date in price_data[s].index else 0
                    entry_price = self.entry_prices.get(s, current_price)
                    unrealized_pnl = positions[s] * (current_price - entry_price) * inst.trade_point_value
                    
                    pos_data[s] = {
                        'contracts': positions[s],
                        'price': current_price,
                        'notional': abs(positions[s]) * current_price * inst.trade_point_value,
                        'margin': abs(positions[s]) * inst.trade_margin,
                        'unrealized_pnl': unrealized_pnl,
                    }
            
            total_margin = sum(p.get('margin', 0) for p in pos_data.values())
            
            # Log portfolio snapshot (only on days with trades or periodically)
            if daily_commission > 0 or i % 20 == 0:  # Log on trade days + every 20 days
                self.trade_logger.cumulative_pnl += daily_pnl - daily_commission
                
                snapshot = PortfolioSnapshot(
                    date=date,
                    cash=cash,
                    equity=equity,
                    total_margin=total_margin,
                    margin_utilization=total_margin / equity if equity > 0 else 0,
                    num_positions=len([c for c in positions.values() if c != 0]),
                    positions=pos_data,
                    daily_pnl=daily_pnl - daily_commission,
                    cumulative_pnl=self.trade_logger.cumulative_pnl,
                )
                self.trade_logger.log_snapshot(snapshot)
            
            stats = self.portfolio_manager.get_portfolio_statistics(
                {s: (positions[s], self.instruments[s], pos_data.get(s, {}).get('price', 0))
                 for s in positions}
            )
            
            results.append({
                'date': date, 
                'equity': equity,
                'daily_return': (daily_pnl - daily_commission) / (equity - daily_pnl + daily_commission) if equity > 0 else 0,
                'num_positions': stats['num_positions'],
                'margin_usage': stats['margin_utilization']
            })
            
            self.position_sizer.account_size = equity
            self.portfolio_manager.account_size = equity
            
            if i % 500 == 0:
                print(f"  Day {i}/{len(dates)}...")
        
        return pd.DataFrame(results).set_index('date')
    
    def generate_trade_report(self, output_path: Optional[str] = None) -> str:
        """Generate a formatted trade report."""
        trades_df = self.trade_logger.get_trades_df()
        snapshots_df = self.trade_logger.get_snapshots_df()
        
        report_lines = []
        report_lines.append("=" * 80)
        report_lines.append("TRADE EXECUTION REPORT")
        report_lines.append("=" * 80)
        report_lines.append(f"Generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        report_lines.append(f"Initial Capital: ${self.initial_capital:,.2f}")
        report_lines.append("")
        
        # Trade Summary
        report_lines.append("-" * 80)
        report_lines.append("TRADE SUMMARY")
        report_lines.append("-" * 80)
        
        if not trades_df.empty:
            total_trades = len(trades_df)
            total_commission = trades_df['commission'].sum()
            buy_trades = len(trades_df[trades_df['side'] == 'BUY'])
            sell_trades = len(trades_df[trades_df['side'] == 'SELL'])
            total_notional = trades_df['notional_value'].sum()
            
            report_lines.append(f"Total Trades:        {total_trades:,}")
            report_lines.append(f"Buy Trades:          {buy_trades:,}")
            report_lines.append(f"Sell Trades:         {sell_trades:,}")
            report_lines.append(f"Total Notional:      ${total_notional:,.2f}")
            report_lines.append(f"Total Commission:    ${total_commission:,.2f}")
            report_lines.append("")
            
            # Trades by instrument
            report_lines.append("Trades by Instrument:")
            for sym in trades_df['signal_symbol'].unique():
                sym_trades = trades_df[trades_df['signal_symbol'] == sym]
                report_lines.append(f"  {sym}: {len(sym_trades)} trades, ${sym_trades['notional_value'].sum():,.2f} notional")
        else:
            report_lines.append("No trades executed.")
        
        report_lines.append("")
        
        # Detailed Trade Log
        report_lines.append("-" * 80)
        report_lines.append("DETAILED TRADE LOG")
        report_lines.append("-" * 80)
        
        if not trades_df.empty:
            for _, trade in trades_df.iterrows():
                report_lines.append(
                    f"{trade['date'].strftime('%Y-%m-%d')} | "
                    f"{trade['trade_symbol']:8} | "
                    f"{trade['side']:4} | "
                    f"{trade['contracts']:4} @ ${trade['price']:,.2f} | "
                    f"Notional: ${trade['notional_value']:>12,.2f} | "
                    f"Comm: ${trade['commission']:>6,.2f} | "
                    f"{trade['reason']}"
                )
        
        report_lines.append("")
        
        # Portfolio Snapshots
        report_lines.append("-" * 80)
        report_lines.append("PORTFOLIO SNAPSHOTS (After Trades)")
        report_lines.append("-" * 80)
        
        if not snapshots_df.empty:
            for _, snap in snapshots_df.iterrows():
                report_lines.append(f"\n{snap['date'].strftime('%Y-%m-%d')}:")
                report_lines.append(f"  Equity:           ${snap['equity']:>15,.2f}")
                report_lines.append(f"  Cash:             ${snap['cash']:>15,.2f}")
                report_lines.append(f"  Total Margin:     ${snap['total_margin']:>15,.2f}")
                report_lines.append(f"  Margin Usage:     {snap['margin_utilization']*100:>14.1f}%")
                report_lines.append(f"  Daily P&L:        ${snap['daily_pnl']:>15,.2f}")
                report_lines.append(f"  Cumulative P&L:   ${snap['cumulative_pnl']:>15,.2f}")
                report_lines.append(f"  Positions:        {snap['num_positions']:>15}")
                
                # Show individual positions
                pos_cols = [c for c in snapshots_df.columns if c.endswith('_contracts')]
                for col in pos_cols:
                    contracts = snap[col]
                    if contracts != 0 and not pd.isna(contracts):
                        sym = col.replace('_contracts', '')
                        price = snap.get(f'{sym}_price', 0)
                        notional = snap.get(f'{sym}_notional', 0)
                        pnl = snap.get(f'{sym}_unrealized_pnl', 0)
                        report_lines.append(
                            f"    {sym}: {int(contracts):+d} contracts @ ${price:,.2f} "
                            f"(Notional: ${notional:,.2f}, Unrealized: ${pnl:+,.2f})"
                        )
        
        report_lines.append("")
        report_lines.append("=" * 80)
        report_lines.append("END OF REPORT")
        report_lines.append("=" * 80)
        
        report_text = "\n".join(report_lines)
        
        if output_path:
            with open(output_path, 'w') as f:
                f.write(report_text)
            print(f"Trade report saved to: {output_path}")
        
        return report_text
    
    def export_to_csv(self, trades_path: str, snapshots_path: str):
        """Export trades and snapshots to CSV files."""
        trades_df = self.trade_logger.get_trades_df()
        snapshots_df = self.trade_logger.get_snapshots_df()
        
        if not trades_df.empty:
            trades_df.to_csv(trades_path, index=False)
            print(f"Trades exported to: {trades_path}")
        
        if not snapshots_df.empty:
            snapshots_df.to_csv(snapshots_path, index=False)
            print(f"Snapshots exported to: {snapshots_path}")


print("✓ Trade logging and reporting classes defined")
# Out:
# ✓ Trade logging and reporting classes defined

# %%
# ==================== BACKTEST ENGINE ====================
class MicroAwareBacktestEngine:
    """
    Backtesting engine that uses signal symbols for price data/signals
    but trade symbols for position sizing and P&L.
    """
    
    def __init__(self, instruments: List[FuturesContract],
                 account=400000, fast=50, slow=100,
                 target_vol=0.20, risk=0.01, target_margin=0.25, commission=2.50):
        
        self.initial_capital = account
        self.commission = commission
        self.strategy = TrendFollowingStrategy(fast, slow)
        self.position_sizer = PositionSizer(account, target_vol, risk)
        self.portfolio_manager = PortfolioManager(account, target_margin)
        
        # Index by SIGNAL symbol (since that's what we use for price data)
        self.instruments = {inst.signal_symbol: inst for inst in instruments}
    
    def load_data(self, start, end=None) -> Dict[str, pd.DataFrame]:
        """Load price data using SIGNAL symbols."""
        print(f"Loading data ({start} to {end or 'latest'})...")
        start_dt = pd.Timestamp(start)
        end_dt = pd.Timestamp(end) if end else None
        
        data = {}
        for signal_sym, inst in self.instruments.items():
            df = load_local_price_data(signal_sym)  # Load SIGNAL symbol data
            if df is not None:
                df = df[df.index >= start_dt]
                if end_dt:
                    df = df[df.index <= end_dt]
                if len(df) > 0:
                    data[signal_sym] = df
                    trade_note = f" -> trade {inst.trade_symbol}" if inst.is_micro else ""
                    print(f"  {signal_sym}: {len(df)} records{trade_note}")
        
        print(f"✓ Loaded {len(data)}/{len(self.instruments)} instruments")
        return data
    
    def run_backtest(self, price_data: Dict[str, pd.DataFrame]) -> pd.DataFrame:
        """Run backtest using signal data but trade specs."""
        # Common dates
        all_dates = None
        for df in price_data.values():
            all_dates = set(df.index) if all_dates is None else all_dates & set(df.index)
        dates = sorted(all_dates)
        
        print(f"Backtest: {dates[0].date()} to {dates[-1].date()} ({len(dates)} days)")
        
        positions = {s: 0 for s in self.instruments}
        equity = self.initial_capital
        results = []
        
        for i, date in enumerate(dates):
            if i < self.strategy.slow_period:
                results.append({'date': date, 'equity': equity, 'daily_return': 0,
                               'num_positions': 0, 'margin_usage': 0})
                continue
            
            new_pos = {}
            for signal_sym, inst in self.instruments.items():
                if signal_sym not in price_data or date not in price_data[signal_sym].index:
                    continue
                
                df = price_data[signal_sym]
                hist = df.loc[df.index <= date, 'Close']
                price = hist.iloc[-1]
                
                # Signal from full-size data
                sig = self.strategy.calculate_signals(hist).iloc[-1]
                vol = self.strategy.calculate_volatility(hist).iloc[-1]
                
                # Size using TRADE specs (micro/mini)
                contracts = self.position_sizer.calculate_position_size(
                    sig, inst, price, vol, positions)
                
                new_pos[signal_sym] = (contracts, inst, price)
            
            # Apply margin constraints using TRADE margin
            managed = self.portfolio_manager.update_positions(
                {s: (c, inst) for s, (c, inst, _) in new_pos.items()})
            
            # Calculate P&L using TRADE point value
            daily_pnl = 0
            comm = 0
            
            for signal_sym in self.instruments:
                if signal_sym in managed and signal_sym in price_data:
                    if date in price_data[signal_sym].index:
                        new_c = managed[signal_sym][0]
                        old_c = positions[signal_sym]
                        if abs(new_c - old_c) > 0:
                            comm += abs(new_c - old_c) * self.commission
            
            if i > 0:
                prev = dates[i-1]
                for signal_sym, c in positions.items():
                    if c != 0 and signal_sym in price_data:
                        df = price_data[signal_sym]
                        if date in df.index and prev in df.index:
                            price_change = df.loc[date, 'Close'] - df.loc[prev, 'Close']
                            inst = self.instruments[signal_sym]
                            # P&L uses TRADE point value
                            daily_pnl += c * price_change * inst.trade_point_value
            
            equity += daily_pnl - comm
            
            # Update positions
            for s, (c, _) in managed.items():
                positions[s] = c
            
            pos_data = {s: (positions[s], self.instruments[s], 
                           new_pos.get(s, (0, None, 0))[2])
                       for s in positions}
            stats = self.portfolio_manager.get_portfolio_statistics(pos_data)
            
            results.append({
                'date': date, 
                'equity': equity,
                'daily_return': (daily_pnl - comm) / (equity - daily_pnl + comm) if equity > 0 else 0,
                'num_positions': stats['num_positions'],
                'margin_usage': stats['margin_utilization']
            })
            
            self.position_sizer.account_size = equity
            self.portfolio_manager.account_size = equity
            
            if i % 500 == 0:
                print(f"  Day {i}/{len(dates)}...")
        
        return pd.DataFrame(results).set_index('date')
    
    def calculate_metrics(self, results: pd.DataFrame) -> Dict:
        ret = results['daily_return']
        eq = results['equity']
        
        total_ret = (eq.iloc[-1] - self.initial_capital) / self.initial_capital
        years = len(ret) / 252
        ann_ret = (1 + total_ret) ** (1 / years) - 1 if years > 0 else 0
        ann_vol = ret.std() * np.sqrt(252)
        sharpe = ann_ret / ann_vol if ann_vol > 0 else 0
        
        cum = (1 + ret).cumprod()
        dd = (cum - cum.expanding().max()) / cum.expanding().max()
        max_dd = dd.min()
        calmar = ann_ret / abs(max_dd) if max_dd != 0 else 0
        
        wins = (ret > 0).sum()
        losses = (ret < 0).sum()
        
        return {
            'Total Return (%)': total_ret * 100,
            'Ann Return (%)': ann_ret * 100,
            'Ann Vol (%)': ann_vol * 100,
            'Sharpe': sharpe,
            'Max DD (%)': max_dd * 100,
            'Calmar': calmar,
            'Win Rate (%)': wins / (wins + losses) * 100 if (wins + losses) > 0 else 0,
            'Final Equity': eq.iloc[-1],
            'Avg Margin (%)': results['margin_usage'].mean() * 100,
        }

print("✓ MicroAwareBacktestEngine defined")
# Out:
# ✓ MicroAwareBacktestEngine defined

# %%
# ==================== RUN BACKTEST WITH LOGGING ====================
engine = MicroAwareBacktestEngineWithLogging(
    instruments=instruments,
    account=CONFIG['initial_capital'],
    fast=CONFIG['fast_period'],
    slow=CONFIG['slow_period'],
    target_vol=CONFIG['target_portfolio_vol'],
    risk=CONFIG['risk_per_trade'],
    target_margin=CONFIG['target_margin_usage'],
    commission=CONFIG['commission_per_contract']
)

price_data = engine.load_data(CONFIG['start_date'], CONFIG['end_date'])
results = engine.run_backtest(price_data)
metrics = engine.calculate_metrics(results)

# ==================== GENERATE REPORTS ====================

# Print trade report to console
report = engine.generate_trade_report()
print(report)

# Save report to file
engine.generate_trade_report(output_path="trade_report.txt")

# Export to CSV for further analysis
engine.export_to_csv(
    trades_path="trades.csv",
    snapshots_path="portfolio_snapshots.csv"
)

# ==================== PERFORMANCE REPORT ====================
print("=" * 60)
print("PERFORMANCE METRICS")
print("=" * 60)
for k, v in metrics.items():
    if 'Equity' in k:
        print(f"  {k:20} ${v:>15,.2f}")
    elif '%' in k:
        print(f"  {k:20} {v:>15.2f}%")
    else:
        print(f"  {k:20} {v:>15.3f}")
# Out:
# Loading data (2015-01-01 to latest)...
#   ES: 502 records -> trade MES
#   NQ: 502 records -> trade MNQ
#   RTY: 502 records -> trade M2K
#   YM: 502 records -> trade MYM
#   FESX: 506 records
#   NKD: 502 records
#   ZB: 502 records
#   ZN: 502 records
#   ZF: 502 records
#   ZT: 502 records
#   FGBL: 506 records
#   FGBM: 506 records
#   FGBS: 506 records
#   CL: 502 records -> trade MCL
#   NG: 502 records -> trade MNG
#   RB: 502 records -> trade MRB
#   BRN: 516 records
#   GC: 502 records -> trade MGC
#   HG: 502 records -> trade MHG
#   PL: 502 records
#   ZC: 502 records -> trade MZC
#   ZS: 502 records -> trade MZS
#   ZW: 502 records -> trade MZW
#   ZM: 502 records -> trade MZM
#   ZL: 502 records -> trade MZL
#   CT: 502 records
#   SB: 502 records
#   CC: 502 records
#   6E: 502 records -> trade M6E
#   6J: 502 records -> trade MJY
#   6B: 502 records -> trade M6B
#   6A: 502 records -> trade M6A
#   6C: 502 records -> trade MCD
#   6S: 502 records -> trade MSF
#   DX: 516 records
#   VX: 502 records -> trade VXM
# ✓ Loaded 36/36 instruments
# Backtest: 2024-01-22 to 2026-01-20 (492 days)
# ================================================================================
# TRADE EXECUTION REPORT
# ================================================================================
# Generated: 2026-01-22 12:25:21
# Initial Capital: $400,000.00
#
# --------------------------------------------------------------------------------
# TRADE SUMMARY
# --------------------------------------------------------------------------------
# Total Trades:        686
# Buy Trades:          359
# Sell Trades:         327
# Total Notional:      $23,072,775.05
# Total Commission:    $3,425.00
#
# Trades by Instrument:
#   ES: 20 trades, $629,826.25 notional
#   RTY: 9 trades, $162,913.50 notional
#   YM: 9 trades, $222,277.00 notional
#   FGBS: 23 trades, $5,552,315.00 notional
#   CL: 12 trades, $170,752.00 notional
#   NG: 29 trades, $110,834.00 notional
#   RB: 10 trades, $136,408.86 notional
#   GC: 8 trades, $201,066.00 notional
#   ZC: 57 trades, $284,187.50 notional
#   ZS: 32 trades, $322,417.50 notional
#   ZW: 49 trades, $360,117.50 notional
#   ZM: 35 trades, $221,819.00 notional
#   ZL: 42 trades, $211,722.00 notional
#   6E: 21 trades, $729,278.13 notional
#   6J: 36 trades, $551,118.75 notional
#   6B: 39 trades, $768,575.62 notional
#   6A: 59 trades, $750,319.00 notional
#   6C: 64 trades, $1,291,880.00 notional
#   6S: 16 trades, $737,896.87 notional
#   VX: 45 trades, $132,957.08 notional
#   ZT: 18 trades, $5,162,546.88 notional
#   ZF: 15 trades, $1,839,687.50 notional
#   FGBM: 10 trades, $1,526,790.00 notional
#   SB: 21 trades, $368,256.00 notional
#   CT: 3 trades, $129,835.00 notional
#   FGBL: 3 trades, $384,400.00 notional
#   ZN: 1 trades, $112,578.12 notional
#
# --------------------------------------------------------------------------------
# DETAILED TRADE LOG
# --------------------------------------------------------------------------------
# 2024-06-17 | MES      | BUY  |    1 @ $5,478.50 | Notional: $   27,392.50 | Comm: $  2.50 | ENTRY_LONG
# 2024-06-17 | M2K      | SELL |    2 @ $2,024.20 | Notional: $   20,242.00 | Comm: $  5.00 | ENTRY_SHORT
# 2024-06-17 | MYM      | SELL |    1 @ $38,818.00 | Notional: $   19,409.00 | Comm: $  2.50 | ENTRY_SHORT
# 2024-06-17 | FGBS     | SELL |    2 @ $105.75 | Notional: $  211,509.99 | Comm: $  5.00 | ENTRY_SHORT
# 2024-06-17 | MCL      | BUY  |    2 @ $80.33 | Notional: $   16,066.00 | Comm: $  5.00 | ENTRY_LONG
# 2024-06-17 | MNG      | BUY  |    1 @ $2.79 | Notional: $    2,788.00 | Comm: $  2.50 | ENTRY_LONG
# 2024-06-17 | MRB      | BUY  |    1 @ $2.45 | Notional: $   10,276.98 | Comm: $  2.50 | ENTRY_LONG
# 2024-06-17 | MGC      | BUY  |    1 @ $2,329.00 | Notional: $   23,290.00 | Comm: $  2.50 | ENTRY_LONG
# 2024-06-17 | MZC      | BUY  |    8 @ $443.75 | Notional: $   17,750.00 | Comm: $ 20.00 | ENTRY_LONG
# 2024-06-17 | MZS      | BUY  |    4 @ $1,157.75 | Notional: $   23,155.00 | Comm: $ 10.00 | ENTRY_LONG
# 2024-06-17 | MZW      | BUY  |    4 @ $591.50 | Notional: $   11,830.00 | Comm: $ 10.00 | ENTRY_LONG
# 2024-06-17 | MZM      | BUY  |    4 @ $360.30 | Notional: $   14,412.00 | Comm: $ 10.00 | ENTRY_LONG
# 2024-06-17 | MZL      | SELL |    5 @ $43.73 | Notional: $   13,119.00 | Comm: $ 12.50 | ENTRY_SHORT
# 2024-06-17 | M6E      | SELL |    5 @ $1.08 | Notional: $   67,387.50 | Comm: $ 12.50 | ENTRY_SHORT
# 2024-06-17 | MJY      | SELL |    5 @ $0.64 | Notional: $   40,178.12 | Comm: $ 12.50 | ENTRY_SHORT
# 2024-06-17 | M6B      | SELL |    8 @ $1.27 | Notional: $   63,565.00 | Comm: $ 20.00 | ENTRY_SHORT
# 2024-06-17 | M6A      | BUY  |    6 @ $0.66 | Notional: $   39,789.00 | Comm: $ 15.00 | ENTRY_LONG
# 2024-06-17 | MCD      | SELL |   11 @ $0.73 | Notional: $   80,162.50 | Comm: $ 27.50 | ENTRY_SHORT
# 2024-06-17 | MSF      | SELL |    4 @ $1.14 | Notional: $   56,777.50 | Comm: $ 10.00 | ENTRY_SHORT
# 2024-06-17 | VXM      | SELL |    5 @ $12.80 | Notional: $    6,400.75 | Comm: $ 12.50 | ENTRY_SHORT
# 2024-06-18 | VXM      | BUY  |    1 @ $14.30 | Notional: $    1,429.61 | Comm: $  2.50 | REDUCE_SHORT
# 2024-06-20 | MGC      | SELL |    1 @ $2,369.00 | Notional: $   23,690.00 | Comm: $  2.50 | EXIT_LONG
# 2024-06-20 | MZL      | SELL |    1 @ $43.97 | Notional: $    2,638.20 | Comm: $  2.50 | ADD_SHORT
# 2024-06-21 | MNG      | BUY  |    1 @ $2.70 | Notional: $    2,705.00 | Comm: $  2.50 | ADD_LONG
# 2024-06-24 | MCL      | SELL |    4 @ $81.63 | Notional: $   32,652.00 | Comm: $ 10.00 | EXIT_LONG
# 2024-06-24 | MZS      | SELL |    1 @ $1,175.25 | Notional: $    5,876.25 | Comm: $  2.50 | REDUCE_LONG
# 2024-06-25 | MRB      | SELL |    2 @ $2.51 | Notional: $   21,123.48 | Comm: $  5.00 | EXIT_LONG
# 2024-06-25 | MGC      | BUY  |    1 @ $2,330.80 | Notional: $   23,308.00 | Comm: $  2.50 | ENTRY_LONG
# 2024-06-25 | MZC      | BUY  |    1 @ $425.50 | Notional: $    2,127.50 | Comm: $  2.50 | ADD_LONG
# 2024-06-25 | MZS      | BUY  |    1 @ $1,163.25 | Notional: $    5,816.25 | Comm: $  2.50 | ADD_LONG
# 2024-06-26 | ZT       | SELL |    1 @ $102.05 | Notional: $  204,109.38 | Comm: $  2.50 | ENTRY_SHORT
# 2024-06-28 | ZT       | BUY  |    1 @ $102.11 | Notional: $  204,218.75 | Comm: $  2.50 | COVER_SHORT
# 2024-06-28 | MZC      | BUY  |    1 @ $407.50 | Notional: $    2,037.50 | Comm: $  2.50 | ADD_LONG
# 2024-07-01 | MYM      | BUY  |    2 @ $39,511.00 | Notional: $   39,511.00 | Comm: $  5.00 | COVER_SHORT
# 2024-07-01 | MZS      | SELL |    1 @ $1,146.00 | Notional: $    5,730.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-07-01 | MZL      | BUY  |    1 @ $46.03 | Notional: $    2,761.80 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-02 | ZT       | SELL |    1 @ $102.05 | Notional: $  204,109.38 | Comm: $  2.50 | ENTRY_SHORT
# 2024-07-02 | M6B      | BUY  |   16 @ $1.27 | Notional: $  126,910.00 | Comm: $ 40.00 | COVER_SHORT
# 2024-07-03 | MCD      | BUY  |    1 @ $0.73 | Notional: $    7,346.00 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-05 | ZT       | BUY  |    1 @ $102.33 | Notional: $  204,656.25 | Comm: $  2.50 | COVER_SHORT
# 2024-07-05 | MGC      | SELL |    1 @ $2,397.70 | Notional: $   23,977.00 | Comm: $  2.50 | EXIT_LONG
# 2024-07-05 | MZC      | SELL |    1 @ $410.50 | Notional: $    2,052.50 | Comm: $  2.50 | REDUCE_LONG
# 2024-07-05 | MZL      | BUY  |    1 @ $49.55 | Notional: $    2,973.00 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-08 | M2K      | BUY  |    4 @ $2,056.70 | Notional: $   41,134.00 | Comm: $ 10.00 | COVER_SHORT
# 2024-07-08 | MYM      | BUY  |    1 @ $39,650.00 | Notional: $   19,825.00 | Comm: $  2.50 | ADD_LONG
# 2024-07-08 | ZT       | SELL |    1 @ $102.30 | Notional: $  204,593.75 | Comm: $  2.50 | ENTRY_SHORT
# 2024-07-08 | M6B      | BUY  |    1 @ $1.28 | Notional: $    8,012.50 | Comm: $  2.50 | ADD_LONG
# 2024-07-08 | M6A      | BUY  |    1 @ $0.68 | Notional: $    6,750.00 | Comm: $  2.50 | ADD_LONG
# 2024-07-08 | MCD      | SELL |    1 @ $0.73 | Notional: $    7,344.50 | Comm: $  2.50 | ADD_SHORT
# 2024-07-09 | MZL      | SELL |    1 @ $46.95 | Notional: $    2,817.00 | Comm: $  2.50 | ADD_SHORT
# 2024-07-10 | MCD      | SELL |    1 @ $0.74 | Notional: $    7,354.00 | Comm: $  2.50 | ADD_SHORT
# 2024-07-10 | VXM      | SELL |    1 @ $12.93 | Notional: $    1,293.35 | Comm: $  2.50 | ADD_SHORT
# 2024-07-11 | MZL      | BUY  |    1 @ $47.12 | Notional: $    2,827.20 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-11 | MJY      | BUY  |    1 @ $0.64 | Notional: $    7,952.50 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-12 | MZS      | BUY  |    1 @ $1,105.00 | Notional: $    5,525.00 | Comm: $  2.50 | ADD_LONG
# 2024-07-12 | MZL      | SELL |    1 @ $46.65 | Notional: $    2,799.00 | Comm: $  2.50 | ADD_SHORT
# 2024-07-15 | MZS      | SELL |    1 @ $1,078.00 | Notional: $    5,390.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-07-16 | M2K      | SELL |    1 @ $2,284.20 | Notional: $   11,421.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-07-16 | MYM      | SELL |    1 @ $41,255.00 | Notional: $   20,627.50 | Comm: $  2.50 | REDUCE_LONG
# 2024-07-16 | M6E      | BUY  |   10 @ $1.09 | Notional: $  136,600.00 | Comm: $ 25.00 | COVER_SHORT
# 2024-07-17 | ZT       | BUY  |    2 @ $102.63 | Notional: $  410,531.25 | Comm: $  5.00 | COVER_SHORT
# 2024-07-17 | VXM      | BUY  |    1 @ $14.81 | Notional: $    1,480.80 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-18 | MSF      | BUY  |    1 @ $1.13 | Notional: $   14,186.88 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-19 | MZC      | SELL |   18 @ $390.50 | Notional: $   35,145.00 | Comm: $ 45.00 | EXIT_LONG
# 2024-07-19 | MZS      | SELL |    6 @ $1,097.25 | Notional: $   32,917.50 | Comm: $ 15.00 | EXIT_LONG
# 2024-07-22 | MZC      | BUY  |    1 @ $400.25 | Notional: $    2,001.25 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-22 | MSF      | BUY  |    6 @ $1.13 | Notional: $   84,873.75 | Comm: $ 15.00 | COVER_SHORT
# 2024-07-24 | VXM      | BUY  |    1 @ $17.07 | Notional: $    1,707.20 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-25 | FGBS     | BUY  |    4 @ $105.92 | Notional: $  423,679.99 | Comm: $ 10.00 | COVER_SHORT
# 2024-07-25 | MNG      | BUY  |    1 @ $2.04 | Notional: $    2,041.00 | Comm: $  2.50 | ADD_LONG
# 2024-07-26 | M6A      | BUY  |    1 @ $0.66 | Notional: $    6,561.00 | Comm: $  2.50 | ADD_LONG
# 2024-07-26 | MCD      | SELL |    1 @ $0.72 | Notional: $    7,237.50 | Comm: $  2.50 | ADD_SHORT
# 2024-07-26 | MSF      | BUY  |    1 @ $1.14 | Notional: $   14,231.25 | Comm: $  2.50 | ADD_LONG
# 2024-07-30 | MNG      | SELL |    1 @ $2.13 | Notional: $    2,126.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-07-30 | MZC      | SELL |    1 @ $388.75 | Notional: $    1,943.75 | Comm: $  2.50 | ADD_SHORT
# 2024-07-30 | MJY      | SELL |    1 @ $0.66 | Notional: $    8,215.62 | Comm: $  2.50 | ADD_SHORT
# 2024-07-30 | MCD      | SELL |    1 @ $0.72 | Notional: $    7,230.00 | Comm: $  2.50 | ADD_SHORT
# 2024-07-31 | ZF       | BUY  |    1 @ $107.89 | Notional: $  107,890.62 | Comm: $  2.50 | ENTRY_LONG
# 2024-07-31 | MNG      | BUY  |    1 @ $2.04 | Notional: $    2,036.00 | Comm: $  2.50 | ADD_LONG
# 2024-07-31 | MJY      | BUY  |    1 @ $0.67 | Notional: $    8,365.00 | Comm: $  2.50 | REDUCE_SHORT
# 2024-07-31 | MCD      | BUY  |    1 @ $0.73 | Notional: $    7,259.00 | Comm: $  2.50 | REDUCE_SHORT
# 2024-08-01 | ZF       | SELL |    1 @ $108.57 | Notional: $  108,570.31 | Comm: $  2.50 | EXIT_LONG
# 2024-08-01 | MZS      | SELL |    1 @ $1,009.00 | Notional: $    5,045.00 | Comm: $  2.50 | ADD_SHORT
# 2024-08-01 | MSF      | SELL |    1 @ $1.15 | Notional: $   14,395.62 | Comm: $  2.50 | REDUCE_LONG
# 2024-08-02 | ZT       | SELL |    1 @ $103.58 | Notional: $  207,156.25 | Comm: $  2.50 | EXIT_LONG
# 2024-08-02 | VXM      | BUY  |    1 @ $21.85 | Notional: $    2,185.27 | Comm: $  2.50 | REDUCE_SHORT
# 2024-08-05 | MZW      | SELL |    8 @ $539.50 | Notional: $   21,580.00 | Comm: $ 20.00 | EXIT_LONG
# 2024-08-05 | VXM      | BUY  |    2 @ $32.10 | Notional: $    6,419.72 | Comm: $  5.00 | COVER_SHORT
# 2024-08-06 | M6B      | SELL |    1 @ $1.27 | Notional: $    7,939.38 | Comm: $  2.50 | REDUCE_LONG
# 2024-08-06 | VXM      | SELL |    1 @ $25.77 | Notional: $    2,577.02 | Comm: $  2.50 | ENTRY_SHORT
# 2024-08-07 | MNG      | SELL |    1 @ $2.11 | Notional: $    2,112.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-08-07 | MJY      | BUY  |    1 @ $0.68 | Notional: $    8,561.25 | Comm: $  2.50 | REDUCE_SHORT
# 2024-08-07 | VXM      | BUY  |    2 @ $25.08 | Notional: $    5,015.32 | Comm: $  5.00 | COVER_SHORT
# 2024-08-08 | MCL      | BUY  |    1 @ $76.19 | Notional: $    7,619.00 | Comm: $  2.50 | REDUCE_SHORT
# 2024-08-08 | MZM      | SELL |    8 @ $319.50 | Notional: $   25,560.00 | Comm: $ 20.00 | EXIT_LONG
# 2024-08-12 | MJY      | SELL |    1 @ $0.68 | Notional: $    8,530.62 | Comm: $  2.50 | ADD_SHORT
# 2024-08-12 | M6B      | BUY  |    1 @ $1.28 | Notional: $    7,984.38 | Comm: $  2.50 | ADD_LONG
# 2024-08-13 | MNG      | BUY  |    1 @ $2.15 | Notional: $    2,148.00 | Comm: $  2.50 | ADD_LONG
# 2024-08-13 | M6B      | SELL |    1 @ $1.29 | Notional: $    8,046.25 | Comm: $  2.50 | REDUCE_LONG
# 2024-08-14 | MNG      | SELL |    1 @ $2.22 | Notional: $    2,219.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-08-14 | MZL      | SELL |    1 @ $40.01 | Notional: $    2,400.60 | Comm: $  2.50 | ADD_SHORT
# 2024-10-03 | MZM      | SELL |    1 @ $332.50 | Notional: $    3,325.00 | Comm: $  2.50 | ADD_SHORT
# 2024-10-03 | M6A      | SELL |    1 @ $0.68 | Notional: $    6,846.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-07 | MZW      | SELL |    1 @ $592.50 | Notional: $    2,962.50 | Comm: $  2.50 | ADD_SHORT
# 2024-10-09 | MGC      | BUY  |    1 @ $2,626.00 | Notional: $   26,260.00 | Comm: $  2.50 | ENTRY_LONG
# 2024-10-10 | MCD      | SELL |    1 @ $0.73 | Notional: $    7,281.50 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-11 | MGC      | SELL |    1 @ $2,676.30 | Notional: $   26,763.00 | Comm: $  2.50 | EXIT_LONG
# 2024-10-14 | MGC      | BUY  |    1 @ $2,665.60 | Notional: $   26,656.00 | Comm: $  2.50 | ENTRY_LONG
# 2024-10-15 | MCD      | BUY  |    1 @ $0.73 | Notional: $    7,263.00 | Comm: $  2.50 | ADD_LONG
# 2024-10-16 | MNG      | SELL |    1 @ $2.37 | Notional: $    2,367.00 | Comm: $  2.50 | ADD_SHORT
# 2024-10-16 | MCD      | SELL |    1 @ $0.73 | Notional: $    7,280.50 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-18 | M6A      | BUY  |    1 @ $0.67 | Notional: $    6,708.00 | Comm: $  2.50 | ADD_LONG
# 2024-10-21 | M6A      | SELL |    1 @ $0.67 | Notional: $    6,658.50 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-21 | MCD      | BUY  |    1 @ $0.72 | Notional: $    7,237.00 | Comm: $  2.50 | ADD_LONG
# 2024-10-22 | MZL      | BUY  |    1 @ $43.69 | Notional: $    2,621.40 | Comm: $  2.50 | REDUCE_SHORT
# 2024-10-22 | MCD      | SELL |    1 @ $0.72 | Notional: $    7,247.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-23 | MZS      | SELL |    1 @ $997.50 | Notional: $    4,987.50 | Comm: $  2.50 | ADD_SHORT
# 2024-10-23 | MZW      | BUY  |    5 @ $578.50 | Notional: $   14,462.50 | Comm: $ 12.50 | COVER_SHORT
# 2024-10-23 | MZL      | SELL |    1 @ $43.39 | Notional: $    2,603.40 | Comm: $  2.50 | ADD_SHORT
# 2024-10-24 | MNG      | BUY  |    1 @ $2.52 | Notional: $    2,522.00 | Comm: $  2.50 | REDUCE_SHORT
# 2024-10-24 | MZW      | BUY  |    5 @ $581.50 | Notional: $   14,537.50 | Comm: $ 12.50 | ENTRY_LONG
# 2024-10-24 | MZL      | BUY  |    1 @ $44.33 | Notional: $    2,659.80 | Comm: $  2.50 | REDUCE_SHORT
# 2024-10-24 | M6E      | SELL |    1 @ $1.08 | Notional: $   13,556.88 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-24 | M6B      | SELL |    1 @ $1.30 | Notional: $    8,107.50 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-24 | MCD      | BUY  |    1 @ $0.72 | Notional: $    7,229.50 | Comm: $  2.50 | ADD_LONG
# 2024-10-25 | MNG      | BUY  |    4 @ $2.56 | Notional: $   10,240.00 | Comm: $ 10.00 | COVER_SHORT
# 2024-10-25 | M6E      | BUY  |    1 @ $1.08 | Notional: $   13,531.88 | Comm: $  2.50 | ADD_LONG
# 2024-10-25 | M6B      | BUY  |    1 @ $1.30 | Notional: $    8,104.38 | Comm: $  2.50 | ADD_LONG
# 2024-10-28 | ZF       | BUY  |    1 @ $107.45 | Notional: $  107,453.12 | Comm: $  2.50 | ENTRY_LONG
# 2024-10-28 | MZM      | SELL |    1 @ $304.80 | Notional: $    3,048.00 | Comm: $  2.50 | ADD_SHORT
# 2024-10-29 | MES      | BUY  |    1 @ $5,871.00 | Notional: $   29,355.00 | Comm: $  2.50 | ENTRY_LONG
# 2024-10-29 | MNG      | SELL |    1 @ $2.86 | Notional: $    2,859.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-10-29 | MZC      | BUY  |   14 @ $413.75 | Notional: $   28,962.50 | Comm: $ 35.00 | COVER_SHORT
# 2024-10-29 | MZL      | SELL |    1 @ $42.80 | Notional: $    2,568.00 | Comm: $  2.50 | ADD_SHORT
# 2024-10-29 | MJY      | BUY  |    1 @ $0.66 | Notional: $    8,197.50 | Comm: $  2.50 | ADD_LONG
# 2024-10-29 | VXM      | BUY  |    1 @ $18.76 | Notional: $    1,875.75 | Comm: $  2.50 | ADD_LONG
# 2024-10-30 | MZL      | BUY  |    1 @ $43.81 | Notional: $    2,628.60 | Comm: $  2.50 | REDUCE_SHORT
# 2024-10-30 | MCD      | BUY  |    1 @ $0.72 | Notional: $    7,205.50 | Comm: $  2.50 | ADD_LONG
# 2024-10-31 | VXM      | SELL |    1 @ $20.96 | Notional: $    2,095.79 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-01 | FGBS     | SELL |    1 @ $106.60 | Notional: $  106,595.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-01 | M6A      | BUY  |    1 @ $0.66 | Notional: $    6,562.50 | Comm: $  2.50 | ADD_LONG
# 2024-11-01 | VXM      | BUY  |    1 @ $20.49 | Notional: $    2,048.80 | Comm: $  2.50 | ADD_LONG
# 2024-11-04 | MCD      | SELL |    1 @ $0.72 | Notional: $    7,205.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-05 | FGBS     | BUY  |    1 @ $106.51 | Notional: $  106,510.00 | Comm: $  2.50 | ADD_LONG
# 2024-11-06 | FGBS     | SELL |    1 @ $106.71 | Notional: $  106,705.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-06 | M6E      | SELL |    1 @ $1.08 | Notional: $   13,440.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-06 | MJY      | SELL |    1 @ $0.65 | Notional: $    8,135.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-06 | MCD      | SELL |    1 @ $0.72 | Notional: $    7,186.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-07 | MES      | SELL |    1 @ $6,003.75 | Notional: $   30,018.75 | Comm: $  2.50 | EXIT_LONG
# 2024-11-07 | FGBS     | BUY  |    1 @ $106.68 | Notional: $  106,685.00 | Comm: $  2.50 | ADD_LONG
# 2024-11-07 | M6B      | SELL |    1 @ $1.30 | Notional: $    8,103.12 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-07 | M6A      | SELL |    1 @ $0.67 | Notional: $    6,670.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-08 | MES      | BUY  |    1 @ $6,025.25 | Notional: $   30,126.25 | Comm: $  2.50 | ENTRY_LONG
# 2024-11-11 | M6B      | BUY  |    1 @ $1.29 | Notional: $    8,038.13 | Comm: $  2.50 | ADD_LONG
# 2024-11-11 | MCD      | SELL |   24 @ $0.72 | Notional: $  172,524.00 | Comm: $ 60.00 | EXIT_LONG
# 2024-11-12 | M6B      | SELL |    1 @ $1.27 | Notional: $    7,960.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-13 | FGBS     | SELL |    1 @ $106.79 | Notional: $  106,785.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-13 | MJY      | BUY  |    1 @ $0.65 | Notional: $    8,070.00 | Comm: $  2.50 | ADD_LONG
# 2024-11-14 | M6B      | BUY  |    1 @ $1.27 | Notional: $    7,929.38 | Comm: $  2.50 | ADD_LONG
# 2024-11-15 | M6E      | SELL |    8 @ $1.05 | Notional: $  105,495.00 | Comm: $ 20.00 | EXIT_LONG
# 2024-11-15 | MJY      | SELL |    1 @ $0.65 | Notional: $    8,135.62 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-15 | M6B      | SELL |    1 @ $1.26 | Notional: $    7,881.88 | Comm: $  2.50 | REDUCE_LONG
# 2024-11-18 | ZT       | BUY  |    1 @ $102.67 | Notional: $  205,343.75 | Comm: $  2.50 | ENTRY_LONG
# 2024-11-18 | MJY      | BUY  |    1 @ $0.65 | Notional: $    8,105.63 | Comm: $  2.50 | ADD_LONG
# 2024-11-18 | M6B      | BUY  |    1 @ $1.27 | Notional: $    7,918.12 | Comm: $  2.50 | ADD_LONG
# 2024-11-19 | MZL      | BUY  |    8 @ $44.84 | Notional: $   21,523.20 | Comm: $ 20.00 | COVER_SHORT
# 2024-11-20 | ZF       | SELL |    2 @ $106.67 | Notional: $  213,343.75 | Comm: $  5.00 | EXIT_LONG
# 2024-11-20 | MZM      | SELL |    1 @ $289.40 | Notional: $    2,894.00 | Comm: $  2.50 | ADD_SHORT
# 2024-11-22 | MGC      | SELL |    1 @ $2,712.20 | Notional: $   27,122.00 | Comm: $  2.50 | EXIT_LONG
# 2024-11-25 | MZC      | BUY  |    4 @ $424.75 | Notional: $    8,495.00 | Comm: $ 10.00 | ADD_LONG
# 2024-11-25 | MZW      | BUY  |    1 @ $535.75 | Notional: $    2,678.75 | Comm: $  2.50 | ADD_LONG
# 2024-11-25 | MJY      | SELL |    8 @ $0.65 | Notional: $   65,050.00 | Comm: $ 20.00 | EXIT_LONG
# 2024-11-26 | M6A      | SELL |   12 @ $0.65 | Notional: $   77,532.00 | Comm: $ 30.00 | EXIT_LONG
# 2024-11-26 | VXM      | BUY  |    1 @ $15.25 | Notional: $    1,525.41 | Comm: $  2.50 | ADD_LONG
# 2024-11-27 | ZT       | SELL |    2 @ $102.77 | Notional: $  411,062.50 | Comm: $  5.00 | EXIT_LONG
# 2024-11-27 | MJY      | BUY  |    1 @ $0.66 | Notional: $    8,296.87 | Comm: $  2.50 | REDUCE_SHORT
# 2024-11-27 | M6B      | SELL |   13 @ $1.27 | Notional: $  102,960.00 | Comm: $ 32.50 | EXIT_LONG
# 2024-11-27 | MSF      | SELL |    6 @ $1.14 | Notional: $   85,218.75 | Comm: $ 15.00 | EXIT_LONG
# 2024-11-29 | FGBS     | BUY  |    1 @ $107.07 | Notional: $  107,070.00 | Comm: $  2.50 | ADD_LONG
# 2024-11-29 | MZC      | SELL |    2 @ $433.00 | Notional: $    4,330.00 | Comm: $  5.00 | REDUCE_LONG
# 2024-12-04 | MZC      | BUY  |    1 @ $430.00 | Notional: $    2,150.00 | Comm: $  2.50 | ADD_LONG
# 2024-12-05 | MZC      | SELL |    1 @ $435.00 | Notional: $    2,175.00 | Comm: $  2.50 | REDUCE_LONG
# 2024-12-06 | MCD      | BUY  |    1 @ $0.71 | Notional: $    7,065.00 | Comm: $  2.50 | REDUCE_SHORT
# 2024-12-06 | VXM      | SELL |    6 @ $14.29 | Notional: $    8,571.30 | Comm: $ 15.00 | EXIT_LONG
# 2024-12-09 | MJY      | SELL |    1 @ $0.66 | Notional: $    8,271.25 | Comm: $  2.50 | ADD_SHORT
# 2024-12-12 | M6B      | SELL |    1 @ $1.27 | Notional: $    7,918.75 | Comm: $  2.50 | ADD_SHORT
# 2024-12-16 | M6B      | BUY  |    1 @ $1.27 | Notional: $    7,923.12 | Comm: $  2.50 | REDUCE_SHORT
# 2024-12-17 | MZC      | BUY  |    1 @ $443.50 | Notional: $    2,217.50 | Comm: $  2.50 | ADD_LONG
# 2024-12-17 | MZS      | SELL |    1 @ $976.75 | Notional: $    4,883.75 | Comm: $  2.50 | ADD_SHORT
# 2024-12-17 | MZW      | BUY  |    1 @ $545.00 | Notional: $    2,725.00 | Comm: $  2.50 | ADD_LONG
# 2024-12-17 | MCD      | SELL |    1 @ $0.70 | Notional: $    7,012.50 | Comm: $  2.50 | ADD_SHORT
# 2024-12-18 | VXM      | BUY  |    1 @ $19.76 | Notional: $    1,976.20 | Comm: $  2.50 | REDUCE_SHORT
# 2024-12-19 | MCD      | BUY  |    1 @ $0.70 | Notional: $    6,973.50 | Comm: $  2.50 | REDUCE_SHORT
# 2024-12-19 | VXM      | BUY  |    1 @ $21.71 | Notional: $    2,171.13 | Comm: $  2.50 | REDUCE_SHORT
# 2024-12-20 | MZS      | BUY  |    1 @ $974.50 | Notional: $    4,872.50 | Comm: $  2.50 | REDUCE_SHORT
# 2024-12-20 | M6A      | SELL |    1 @ $0.63 | Notional: $    6,267.50 | Comm: $  2.50 | ADD_SHORT
# 2024-12-20 | VXM      | SELL |    1 @ $18.26 | Notional: $    1,826.06 | Comm: $  2.50 | ADD_SHORT
# 2025-03-17 | MZC      | SELL |    1 @ $461.00 | Notional: $    2,305.00 | Comm: $  2.50 | REDUCE_LONG
# 2025-03-18 | MZC      | BUY  |    1 @ $458.75 | Notional: $    2,293.75 | Comm: $  2.50 | ADD_LONG
# 2025-03-18 | M6A      | SELL |    1 @ $0.64 | Notional: $    6,365.00 | Comm: $  2.50 | ADD_SHORT
# 2025-03-19 | MJY      | BUY  |    1 @ $0.68 | Notional: $    8,480.00 | Comm: $  2.50 | ADD_LONG
# 2025-03-19 | VXM      | BUY  |    1 @ $19.75 | Notional: $    1,975.13 | Comm: $  2.50 | ADD_LONG
# 2025-03-20 | MZC      | SELL |    1 @ $469.00 | Notional: $    2,345.00 | Comm: $  2.50 | REDUCE_LONG
# 2025-03-20 | M6A      | BUY  |    1 @ $0.63 | Notional: $    6,305.50 | Comm: $  2.50 | REDUCE_SHORT
# 2025-03-21 | ZF       | BUY  |    1 @ $108.02 | Notional: $  108,015.62 | Comm: $  2.50 | ENTRY_LONG
# 2025-03-21 | M6E      | SELL |    1 @ $1.09 | Notional: $   13,589.37 | Comm: $  2.50 | ADD_SHORT
# 2025-03-24 | ZF       | SELL |    1 @ $107.62 | Notional: $  107,625.00 | Comm: $  2.50 | EXIT_LONG
# 2025-03-24 | M6A      | SELL |    1 @ $0.63 | Notional: $    6,288.00 | Comm: $  2.50 | ADD_SHORT
# 2025-03-25 | M6E      | BUY  |    6 @ $1.08 | Notional: $   81,360.00 | Comm: $ 15.00 | COVER_SHORT
# 2025-03-25 | M6A      | BUY  |    1 @ $0.63 | Notional: $    6,303.00 | Comm: $  2.50 | REDUCE_SHORT
# 2025-03-26 | MZS      | BUY  |    1 @ $1,001.00 | Notional: $    5,005.00 | Comm: $  2.50 | ADD_LONG
# 2025-03-26 | M6E      | SELL |    1 @ $1.08 | Notional: $   13,505.63 | Comm: $  2.50 | REDUCE_LONG
# 2025-03-27 | MZC      | BUY  |    1 @ $450.00 | Notional: $    2,250.00 | Comm: $  2.50 | ADD_LONG
# 2025-03-27 | MZS      | SELL |    1 @ $1,016.75 | Notional: $    5,083.75 | Comm: $  2.50 | REDUCE_LONG
# 2025-03-27 | M6B      | BUY  |   10 @ $1.29 | Notional: $   80,925.00 | Comm: $ 25.00 | COVER_SHORT
# 2025-03-28 | MCL      | SELL |    4 @ $69.36 | Notional: $   27,744.00 | Comm: $ 10.00 | EXIT_LONG
# 2025-03-28 | MZS      | BUY  |    1 @ $1,023.00 | Notional: $    5,115.00 | Comm: $  2.50 | ADD_LONG
# 2025-03-28 | MZM      | BUY  |    1 @ $293.50 | Notional: $    2,935.00 | Comm: $  2.50 | ADD_LONG
# 2025-03-31 | MZC      | SELL |    1 @ $457.25 | Notional: $    2,286.25 | Comm: $  2.50 | REDUCE_LONG
# 2025-03-31 | M6E      | BUY  |    1 @ $1.09 | Notional: $   13,577.50 | Comm: $  2.50 | ADD_LONG
# 2025-03-31 | M6B      | BUY  |    1 @ $1.29 | Notional: $    8,069.38 | Comm: $  2.50 | ADD_LONG
# 2025-06-20 | SB       | BUY  |    1 @ $16.10 | Notional: $   18,032.00 | Comm: $  2.50 | COVER_SHORT
# 2025-06-24 | SB       | SELL |    1 @ $15.77 | Notional: $   17,662.40 | Comm: $  2.50 | ENTRY_SHORT
# 2025-06-25 | SB       | BUY  |    1 @ $15.98 | Notional: $   17,897.60 | Comm: $  2.50 | COVER_SHORT
# 2025-06-26 | VXM      | SELL |    2 @ $18.91 | Notional: $    3,782.24 | Comm: $  5.00 | EXIT_LONG
# 2025-06-27 | SB       | SELL |    1 @ $15.81 | Notional: $   17,707.20 | Comm: $  2.50 | ENTRY_SHORT
# 2025-06-30 | SB       | BUY  |    1 @ $16.20 | Notional: $   18,144.00 | Comm: $  2.50 | COVER_SHORT
# 2025-06-30 | MCD      | SELL |    1 @ $0.74 | Notional: $    7,368.00 | Comm: $  2.50 | REDUCE_LONG
# 2025-07-01 | MCD      | BUY  |    1 @ $0.74 | Notional: $    7,353.50 | Comm: $  2.50 | ADD_LONG
# 2025-07-02 | M2K      | BUY  |    2 @ $2,244.30 | Notional: $   22,443.00 | Comm: $  5.00 | COVER_SHORT
# 2025-07-02 | MZC      | BUY  |    1 @ $418.00 | Notional: $    2,090.00 | Comm: $  2.50 | REDUCE_SHORT
# 2025-07-02 | MZW      | BUY  |    1 @ $564.00 | Notional: $    2,820.00 | Comm: $  2.50 | REDUCE_SHORT
# 2025-07-02 | SB       | SELL |    1 @ $15.58 | Notional: $   17,449.60 | Comm: $  2.50 | ENTRY_SHORT
# 2025-07-02 | M6A      | BUY  |    2 @ $0.66 | Notional: $   13,186.00 | Comm: $  5.00 | ADD_LONG
# 2025-07-02 | MCD      | BUY  |    1 @ $0.74 | Notional: $    7,383.50 | Comm: $  2.50 | ADD_LONG
# 2025-07-03 | SB       | BUY  |    1 @ $16.38 | Notional: $   18,345.60 | Comm: $  2.50 | COVER_SHORT
# 2025-07-07 | FGBS     | BUY  |    1 @ $107.28 | Notional: $  107,280.00 | Comm: $  2.50 | ADD_LONG
# ...
#     6A: +9 contracts @ $0.67 (Notional: $60,246.00, Unrealized: $-36.00)
#     6C: -12 contracts @ $0.72 (Notional: $86,784.00, Unrealized: $+318.00)
#     6S: -4 contracts @ $1.26 (Notional: $62,975.00, Unrealized: $+665.00)
#     VX: +2 contracts @ $16.52 (Notional: $3,303.86, Unrealized: $-478.42)
#     ZT: +1 contracts @ $104.34 (Notional: $208,671.88, Unrealized: $+812.50)
#     ZF: -1 contracts @ $109.16 (Notional: $109,164.06, Unrealized: $-0.00)
#     FGBM: -1 contracts @ $116.33 (Notional: $116,330.00, Unrealized: $-300.00)
#     ZN: -1 contracts @ $112.25 (Notional: $112,250.00, Unrealized: $+328.12)
#
# 2026-01-09:
#   Equity:           $     386,871.40
#   Cash:             $     352,281.51
#   Total Margin:     $      36,546.72
#   Margin Usage:                9.4%
#   Daily P&L:        $         250.23
#   Cumulative P&L:   $     -11,189.35
#   Positions:                     23
#     RTY: +1 contracts @ $2,636.90 (Notional: $13,184.50, Unrealized: $+1,963.00)
#     YM: +1 contracts @ $49,726.00 (Notional: $24,863.00, Unrealized: $+2,607.00)
#     FGBS: -6 contracts @ $106.82 (Notional: $640,949.98, Unrealized: $+1,890.01)
#     CL: -2 contracts @ $59.12 (Notional: $11,824.00, Unrealized: $+858.00)
#     NG: +1 contracts @ $3.17 (Notional: $3,169.00, Unrealized: $-1,063.00)
#     RB: -1 contracts @ $1.78 (Notional: $7,478.52, Unrealized: $+747.60)
#     ZC: +10 contracts @ $445.75 (Notional: $22,287.50, Unrealized: $+1,137.50)
#     ZS: +4 contracts @ $1,062.50 (Notional: $21,250.00, Unrealized: $+615.00)
#     ZW: +7 contracts @ $517.25 (Notional: $18,103.75, Unrealized: $-831.25)
#     ZM: +6 contracts @ $303.70 (Notional: $18,222.00, Unrealized: $+1,722.00)
#     ZL: -7 contracts @ $49.69 (Notional: $20,869.80, Unrealized: $+751.80)
#     6E: -6 contracts @ $1.17 (Notional: $87,525.00, Unrealized: $-510.00)
#     6J: -6 contracts @ $0.64 (Notional: $47,760.00, Unrealized: $+3,465.00)
#     6B: -8 contracts @ $1.34 (Notional: $67,030.00, Unrealized: $+1,175.00)
#     6A: +9 contracts @ $0.67 (Notional: $60,187.50, Unrealized: $-94.50)
#     6C: -12 contracts @ $0.72 (Notional: $86,508.00, Unrealized: $+594.00)
#     6S: -4 contracts @ $1.26 (Notional: $62,850.00, Unrealized: $+790.00)
#     VX: +2 contracts @ $16.16 (Notional: $3,231.04, Unrealized: $-551.24)
#     ZT: +1 contracts @ $104.23 (Notional: $208,468.75, Unrealized: $+609.38)
#     ZF: -1 contracts @ $109.05 (Notional: $109,046.88, Unrealized: $+117.19)
#     FGBM: -1 contracts @ $116.34 (Notional: $116,340.00, Unrealized: $-310.00)
#     FGBL: -1 contracts @ $127.95 (Notional: $127,950.00, Unrealized: $-0.00)
#     ZN: -1 contracts @ $112.22 (Notional: $112,218.75, Unrealized: $+359.38)
#
# 2026-01-12:
#   Equity:           $     383,775.52
#   Cash:             $     347,228.80
#   Total Margin:     $      37,646.36
#   Margin Usage:                9.8%
#   Daily P&L:        $      -3,095.88
#   Cumulative P&L:   $     -14,285.23
#   Positions:                     24
#     RTY: +1 contracts @ $2,649.30 (Notional: $13,246.50, Unrealized: $+2,025.00)
#     YM: +1 contracts @ $49,809.00 (Notional: $24,904.50, Unrealized: $+2,648.50)
#     FGBS: -6 contracts @ $106.83 (Notional: $640,980.01, Unrealized: $+1,859.99)
#     CL: -2 contracts @ $59.50 (Notional: $11,900.00, Unrealized: $+782.00)
#     NG: +1 contracts @ $3.41 (Notional: $3,409.00, Unrealized: $-823.00)
#     RB: -1 contracts @ $1.79 (Notional: $7,533.96, Unrealized: $+692.16)
#     ZC: +9 contracts @ $421.50 (Notional: $18,967.50, Unrealized: $-67.50)
#     ZS: +4 contracts @ $1,049.00 (Notional: $20,980.00, Unrealized: $+345.00)
#     ZW: +7 contracts @ $511.25 (Notional: $17,893.75, Unrealized: $-1,041.25)
#     ZM: +6 contracts @ $298.30 (Notional: $17,898.00, Unrealized: $+1,398.00)
#     ZL: -7 contracts @ $50.27 (Notional: $21,113.40, Unrealized: $+508.20)
#     6E: -6 contracts @ $1.17 (Notional: $87,798.75, Unrealized: $-783.75)
#     6J: -6 contracts @ $0.64 (Notional: $47,681.25, Unrealized: $+3,543.75)
#     6B: -7 contracts @ $1.35 (Notional: $58,909.38, Unrealized: $+770.00)
#     6A: +9 contracts @ $0.67 (Notional: $60,435.00, Unrealized: $+153.00)
#     6C: -12 contracts @ $0.72 (Notional: $86,748.00, Unrealized: $+354.00)
#     6S: -4 contracts @ $1.26 (Notional: $63,155.00, Unrealized: $+485.00)
#     VX: +2 contracts @ $16.12 (Notional: $3,224.48, Unrealized: $-557.80)
#     ZT: +1 contracts @ $104.23 (Notional: $208,453.12, Unrealized: $+593.75)
#     ZF: -1 contracts @ $109.02 (Notional: $109,015.62, Unrealized: $+148.44)
#     FGBM: -1 contracts @ $116.43 (Notional: $116,430.00, Unrealized: $-400.00)
#     SB: -1 contracts @ $14.84 (Notional: $16,620.80, Unrealized: $-0.00)
#     FGBL: -1 contracts @ $128.17 (Notional: $128,170.00, Unrealized: $-220.00)
#     ZN: -1 contracts @ $112.14 (Notional: $112,140.62, Unrealized: $+437.50)
#
# 2026-01-13:
#   Equity:           $     382,651.77
#   Cash:             $     345,005.41
#   Total Margin:     $      37,103.77
#   Margin Usage:                9.7%
#   Daily P&L:        $      -1,123.75
#   Cumulative P&L:   $     -15,408.98
#   Positions:                     23
#     RTY: +1 contracts @ $2,647.80 (Notional: $13,239.00, Unrealized: $+2,017.50)
#     YM: +1 contracts @ $49,409.00 (Notional: $24,704.50, Unrealized: $+2,448.50)
#     FGBS: -6 contracts @ $106.83 (Notional: $641,009.99, Unrealized: $+1,830.00)
#     CL: -2 contracts @ $61.15 (Notional: $12,230.00, Unrealized: $+452.00)
#     NG: +1 contracts @ $3.42 (Notional: $3,419.00, Unrealized: $-813.00)
#     RB: -1 contracts @ $1.83 (Notional: $7,671.30, Unrealized: $+554.82)
#     ZC: +9 contracts @ $419.75 (Notional: $18,888.75, Unrealized: $-146.25)
#     ZS: +4 contracts @ $1,038.75 (Notional: $20,775.00, Unrealized: $+140.00)
#     ZW: +7 contracts @ $510.50 (Notional: $17,867.50, Unrealized: $-1,067.50)
#     ZM: +6 contracts @ $291.60 (Notional: $17,496.00, Unrealized: $+996.00)
#     ZL: -6 contracts @ $51.20 (Notional: $18,432.00, Unrealized: $+100.80)
#     6E: -6 contracts @ $1.17 (Notional: $87,622.50, Unrealized: $-607.50)
#     6J: -6 contracts @ $0.63 (Notional: $47,381.25, Unrealized: $+3,843.75)
#     6B: -7 contracts @ $1.34 (Notional: $58,773.75, Unrealized: $+905.62)
#     6A: +9 contracts @ $0.67 (Notional: $60,133.50, Unrealized: $-148.50)
#     6C: -12 contracts @ $0.72 (Notional: $86,640.00, Unrealized: $+462.00)
#     6S: -4 contracts @ $1.26 (Notional: $62,857.50, Unrealized: $+782.50)
#     VX: +2 contracts @ $16.60 (Notional: $3,319.84, Unrealized: $-462.44)
#     ZT: +2 contracts @ $104.26 (Notional: $417,031.25, Unrealized: $+1,312.50)
#     ZF: -1 contracts @ $109.12 (Notional: $109,117.19, Unrealized: $+46.88)
#     FGBM: -1 contracts @ $116.42 (Notional: $116,420.00, Unrealized: $-390.00)
#     FGBL: -1 contracts @ $128.09 (Notional: $128,090.00, Unrealized: $-140.00)
#     ZN: -1 contracts @ $112.27 (Notional: $112,265.62, Unrealized: $+312.50)
#
# 2026-01-14:
#   Equity:           $     381,714.50
#   Cash:             $     344,610.73
#   Total Margin:     $      38,554.44
#   Margin Usage:               10.1%
#   Daily P&L:        $        -937.27
#   Cumulative P&L:   $     -16,346.25
#   Positions:                     24
#     RTY: +1 contracts @ $2,666.10 (Notional: $13,330.50, Unrealized: $+2,109.00)
#     YM: +1 contracts @ $49,356.00 (Notional: $24,678.00, Unrealized: $+2,422.00)
#     FGBS: -6 contracts @ $106.87 (Notional: $641,220.02, Unrealized: $+1,619.98)
#     CL: -2 contracts @ $62.02 (Notional: $12,404.00, Unrealized: $+278.00)
#     NG: +1 contracts @ $3.12 (Notional: $3,120.00, Unrealized: $-1,112.00)
#     RB: -1 contracts @ $1.83 (Notional: $7,687.68, Unrealized: $+538.44)
#     ZC: +9 contracts @ $422.00 (Notional: $18,990.00, Unrealized: $-45.00)
#     ZS: +4 contracts @ $1,042.50 (Notional: $20,850.00, Unrealized: $+215.00)
#     ZW: +7 contracts @ $512.50 (Notional: $17,937.50, Unrealized: $-997.50)
#     ZM: +6 contracts @ $291.90 (Notional: $17,514.00, Unrealized: $+1,014.00)
#     ZL: -6 contracts @ $50.98 (Notional: $18,352.80, Unrealized: $+180.00)
#     6E: -6 contracts @ $1.17 (Notional: $87,521.25, Unrealized: $-506.25)
#     6J: -6 contracts @ $0.63 (Notional: $47,565.00, Unrealized: $+3,660.00)
#     6B: -7 contracts @ $1.34 (Notional: $58,751.88, Unrealized: $+927.50)
#     6A: +9 contracts @ $0.67 (Notional: $60,124.50, Unrealized: $-157.50)
#     6C: -12 contracts @ $0.72 (Notional: $86,718.00, Unrealized: $+384.00)
#     6S: -4 contracts @ $1.26 (Notional: $62,872.50, Unrealized: $+767.50)
#     VX: +2 contracts @ $17.29 (Notional: $3,457.40, Unrealized: $-324.88)
#     ZT: +2 contracts @ $104.28 (Notional: $417,125.00, Unrealized: $+1,406.25)
#     ZF: -1 contracts @ $109.23 (Notional: $109,226.56, Unrealized: $-62.50)
#     FGBM: -1 contracts @ $116.55 (Notional: $116,550.00, Unrealized: $-520.00)
#     SB: -1 contracts @ $14.68 (Notional: $16,441.60, Unrealized: $-0.00)
#     FGBL: -1 contracts @ $128.36 (Notional: $128,360.00, Unrealized: $-410.00)
#     ZN: -1 contracts @ $112.47 (Notional: $112,468.75, Unrealized: $+109.38)
#
# 2026-01-15:
#   Equity:           $     383,011.61
#   Cash:             $     344,457.17
#   Total Margin:     $      38,189.68
#   Margin Usage:               10.0%
#   Daily P&L:        $       1,297.11
#   Cumulative P&L:   $     -15,049.15
#   Positions:                     24
#     RTY: +1 contracts @ $2,688.40 (Notional: $13,442.00, Unrealized: $+2,220.50)
#     YM: +1 contracts @ $49,639.00 (Notional: $24,819.50, Unrealized: $+2,563.50)
#     FGBS: -6 contracts @ $106.84 (Notional: $641,039.98, Unrealized: $+1,800.02)
#     CL: -2 contracts @ $59.19 (Notional: $11,838.00, Unrealized: $+844.00)
#     NG: +1 contracts @ $3.13 (Notional: $3,128.00, Unrealized: $-1,104.00)
#     RB: -1 contracts @ $1.78 (Notional: $7,491.96, Unrealized: $+734.16)
#     ZC: +9 contracts @ $420.25 (Notional: $18,911.25, Unrealized: $-123.75)
#     ZS: +4 contracts @ $1,053.00 (Notional: $21,060.00, Unrealized: $+425.00)
#     ZW: +7 contracts @ $510.50 (Notional: $17,867.50, Unrealized: $-1,067.50)
#     ZM: +6 contracts @ $289.20 (Notional: $17,352.00, Unrealized: $+852.00)
#     ZL: -6 contracts @ $52.97 (Notional: $19,069.20, Unrealized: $-536.40)
#     6E: -6 contracts @ $1.16 (Notional: $87,330.00, Unrealized: $-315.00)
#     6J: -6 contracts @ $0.63 (Notional: $47,538.75, Unrealized: $+3,686.25)
#     6B: -7 contracts @ $1.34 (Notional: $58,555.00, Unrealized: $+1,124.37)
#     6A: +9 contracts @ $0.67 (Notional: $60,322.50, Unrealized: $+40.50)
#     6C: +12 contracts @ $0.72 (Notional: $86,598.00, Unrealized: $+0.00)
#     6S: -4 contracts @ $1.25 (Notional: $62,632.50, Unrealized: $+1,007.50)
#     VX: +3 contracts @ $16.50 (Notional: $4,951.23, Unrealized: $-722.19)
#     ZT: -1 contracts @ $104.18 (Notional: $208,359.38, Unrealized: $-0.00)
#     ZF: -1 contracts @ $109.01 (Notional: $109,007.81, Unrealized: $+156.25)
#     FGBM: -1 contracts @ $116.51 (Notional: $116,510.00, Unrealized: $-480.00)
#     SB: -1 contracts @ $14.57 (Notional: $16,318.40, Unrealized: $+123.20)
#     FGBL: -1 contracts @ $128.42 (Notional: $128,420.00, Unrealized: $-470.00)
#     ZN: -1 contracts @ $112.22 (Notional: $112,218.75, Unrealized: $+359.38)
#
# 2026-01-16:
#   Equity:           $     384,472.67
#   Cash:             $     346,282.98
#   Total Margin:     $      38,189.68
#   Margin Usage:                9.9%
#   Daily P&L:        $       1,461.06
#   Cumulative P&L:   $     -13,588.09
#   Positions:                     24
#     RTY: +1 contracts @ $2,691.20 (Notional: $13,456.00, Unrealized: $+2,234.50)
#     YM: +1 contracts @ $49,547.00 (Notional: $24,773.50, Unrealized: $+2,517.50)
#     FGBS: -6 contracts @ $106.80 (Notional: $640,800.02, Unrealized: $+2,039.98)
#     CL: -2 contracts @ $59.44 (Notional: $11,888.00, Unrealized: $+794.00)
#     NG: +1 contracts @ $3.10 (Notional: $3,103.00, Unrealized: $-1,129.00)
#     RB: -1 contracts @ $1.79 (Notional: $7,497.84, Unrealized: $+728.28)
#     ZC: +9 contracts @ $424.75 (Notional: $19,113.75, Unrealized: $+78.75)
#     ZS: +4 contracts @ $1,057.75 (Notional: $21,155.00, Unrealized: $+520.00)
#     ZW: +7 contracts @ $518.00 (Notional: $18,130.00, Unrealized: $-805.00)
#     ZM: +6 contracts @ $290.00 (Notional: $17,400.00, Unrealized: $+900.00)
#     ZL: -6 contracts @ $52.61 (Notional: $18,939.60, Unrealized: $-406.80)
#     6E: -6 contracts @ $1.16 (Notional: $87,202.50, Unrealized: $-187.50)
#     6J: -6 contracts @ $0.64 (Notional: $47,662.50, Unrealized: $+3,562.50)
#     6B: -7 contracts @ $1.34 (Notional: $58,537.50, Unrealized: $+1,141.87)
#     6A: +9 contracts @ $0.67 (Notional: $60,156.00, Unrealized: $-126.00)
#     6C: +12 contracts @ $0.72 (Notional: $86,436.00, Unrealized: $-162.00)
#     6S: -4 contracts @ $1.25 (Notional: $62,612.50, Unrealized: $+1,027.50)
#     VX: -3 contracts @ $16.64 (Notional: $4,991.67, Unrealized: $-0.00)
#     ZT: -1 contracts @ $104.12 (Notional: $208,234.38, Unrealized: $+125.00)
#     ZF: -1 contracts @ $108.73 (Notional: $108,726.56, Unrealized: $+437.50)
#     FGBM: -1 contracts @ $116.37 (Notional: $116,370.00, Unrealized: $-340.00)
#     SB: -1 contracts @ $14.96 (Notional: $16,755.20, Unrealized: $-313.60)
#     FGBL: -1 contracts @ $128.14 (Notional: $128,140.00, Unrealized: $-190.00)
#     ZN: -1 contracts @ $111.75 (Notional: $111,750.00, Unrealized: $+828.12)
#
# 2026-01-20:
#   Equity:           $     382,082.77
#   Cash:             $     343,893.08
#   Total Margin:     $      36,600.25
#   Margin Usage:                9.6%
#   Daily P&L:        $      -2,389.90
#   Cumulative P&L:   $     -15,977.98
#   Positions:                     24
#     RTY: +1 contracts @ $2,658.70 (Notional: $13,293.50, Unrealized: $+2,072.00)
#     YM: +1 contracts @ $48,666.00 (Notional: $24,333.00, Unrealized: $+2,077.00)
#     FGBS: -6 contracts @ $106.89 (Notional: $641,340.00, Unrealized: $+1,500.00)
#     CL: -2 contracts @ $60.36 (Notional: $12,072.00, Unrealized: $+610.00)
#     NG: +1 contracts @ $3.91 (Notional: $3,907.00, Unrealized: $-325.00)
#     RB: -1 contracts @ $1.82 (Notional: $7,659.96, Unrealized: $+566.16)
#     ZC: +9 contracts @ $423.75 (Notional: $19,068.75, Unrealized: $+33.75)
#     ZS: +4 contracts @ $1,053.00 (Notional: $21,060.00, Unrealized: $+425.00)
#     ZW: +7 contracts @ $510.25 (Notional: $17,858.75, Unrealized: $-1,076.25)
#     ZM: +6 contracts @ $291.60 (Notional: $17,496.00, Unrealized: $+996.00)
#     ZL: -6 contracts @ $52.56 (Notional: $18,921.60, Unrealized: $-388.80)
#     6E: -5 contracts @ $1.17 (Notional: $73,390.63, Unrealized: $-878.13)
#     6J: -6 contracts @ $0.63 (Notional: $47,602.50, Unrealized: $+3,622.50)
#     6B: -7 contracts @ $1.34 (Notional: $58,743.13, Unrealized: $+936.25)
#     6A: +9 contracts @ $0.67 (Notional: $60,597.00, Unrealized: $+315.00)
#     6C: +12 contracts @ $0.72 (Notional: $86,946.00, Unrealized: $+348.00)
#     6S: -3 contracts @ $1.27 (Notional: $47,726.25, Unrealized: $+3.75)
#     VX: -2 contracts @ $20.22 (Notional: $4,044.56, Unrealized: $-716.78)
#     ZT: -1 contracts @ $104.12 (Notional: $208,234.38, Unrealized: $+125.00)
#     ZF: -1 contracts @ $108.62 (Notional: $108,625.00, Unrealized: $+539.06)
#     FGBM: -1 contracts @ $116.48 (Notional: $116,480.00, Unrealized: $-450.00)
#     SB: -1 contracts @ $14.72 (Notional: $16,486.40, Unrealized: $-44.80)
#     FGBL: -1 contracts @ $127.97 (Notional: $127,970.00, Unrealized: $-20.00)
#     ZN: -1 contracts @ $111.42 (Notional: $111,421.88, Unrealized: $+1,156.25)
#
# ================================================================================
# END OF REPORT
# ================================================================================
# Trade report saved to: trade_report.txt
# Trades exported to: trades.csv
# Snapshots exported to: portfolio_snapshots.csv
# ============================================================
# PERFORMANCE METRICS
# ============================================================
#   Total Return (%)               -4.48%
#   Ann Return (%)                 -2.32%
#   Ann Vol (%)                     4.83%
#   Sharpe                        -0.480
#   Max DD (%)                     -6.86%
#   Calmar                        -0.338
#   Win Rate (%)                   47.45%
#   Final Equity         $     382,082.77
#   Avg Margin (%)                  5.51%

# %%
print("\nRunning backtest...")
results = engine.run_backtest(price_data)
metrics = engine.calculate_metrics(results)
print(f"\n✓ Complete! Final equity: ${metrics['Final Equity']:,.2f}")
# Out:
# Running backtest...
# Backtest: 2024-01-22 to 2026-01-20 (492 days)
#
# ✓ Complete! Final equity: $382,070.90

# %%
# ==================== PERFORMANCE REPORT ====================
print("=" * 60)
print("PERFORMANCE METRICS")
print("=" * 60)
for k, v in metrics.items():
    if 'Equity' in k:
        print(f"  {k:20} ${v:>15,.2f}")
    elif '%' in k:
        print(f"  {k:20} {v:>15.2f}%")
    else:
        print(f"  {k:20} {v:>15.3f}")
# Out:
# ============================================================
# PERFORMANCE METRICS
# ============================================================
#   Total Return (%)               -4.48%
#   Ann Return (%)                 -2.32%
#   Ann Vol (%)                     4.83%
#   Sharpe                        -0.480
#   Max DD (%)                     -6.79%
#   Calmar                        -0.342
#   Win Rate (%)                   47.45%
#   Final Equity         $     382,070.90
#   Avg Margin (%)                  5.50%

# %%
# ==================== VISUALIZATION ====================
fig, axes = plt.subplots(3, 1, figsize=(14, 12))

# Equity curve
ax1 = axes[0]
ax1.plot(results.index, results['equity'], linewidth=1.5, color='blue')
ax1.axhline(CONFIG['initial_capital'], color='gray', linestyle='--', alpha=0.5)
ax1.set_title('Equity Curve (Using Micro/Mini Contracts)', fontsize=14, fontweight='bold')
ax1.set_ylabel('Equity ($)')
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
ax1.grid(True, alpha=0.3)

# Drawdown
ax2 = axes[1]
cum = (1 + results['daily_return']).cumprod()
dd = (cum - cum.expanding().max()) / cum.expanding().max() * 100
ax2.fill_between(results.index, 0, dd, alpha=0.5, color='red')
ax2.set_title('Drawdown', fontsize=14, fontweight='bold')
ax2.set_ylabel('Drawdown (%)')
ax2.grid(True, alpha=0.3)

# Margin
ax3 = axes[2]
ax3.plot(results.index, results['margin_usage'] * 100, linewidth=1, color='purple', alpha=0.7)
ax3.axhline(CONFIG['target_margin_usage'] * 100, color='red', linestyle='--', label='Target')
ax3.fill_between(results.index, 0, results['margin_usage'] * 100, alpha=0.3, color='purple')
ax3.set_title('Margin Utilization', fontsize=14, fontweight='bold')
ax3.set_ylabel('Margin (%)')
ax3.legend()
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('backtest_results_micros.png', dpi=150, bbox_inches='tight')
plt.show()
print("✓ Charts saved to backtest_results_micros.png")
# Out:
# ✓ Charts saved to backtest_results_micros.png

# %%
# ==================== POSITION SIZE COMPARISON ====================
# Show how position sizes differ between full-size and micro

print("\n" + "=" * 80)
print("POSITION SIZE GRANULARITY COMPARISON")
print("=" * 80)
print(f"Account: ${CONFIG['initial_capital']:,} | Risk per trade: {CONFIG['risk_per_trade']*100}%")
print("-" * 80)
print(f"{'Signal':<8} {'Trade':<8} {'Price':>10} {'Vol':>8} {'Full-Size':>12} {'Micro':>12} {'Improvement':>12}")
print("-" * 80)

# Get latest prices and calculate example positions
risk_capital = CONFIG['initial_capital'] * CONFIG['risk_per_trade']

for signal_sym, inst in sorted(engine.instruments.items()):
    if signal_sym in price_data and len(price_data[signal_sym]) > 60:
        df = price_data[signal_sym]
        price = df['Close'].iloc[-1]
        vol = df['Close'].pct_change().rolling(60).std().iloc[-1] * np.sqrt(252)
        
        if np.isnan(vol) or vol == 0:
            continue
        
        # Full-size position
        full_dollar_vol = price * inst.signal_point_value * vol
        full_contracts = risk_capital / full_dollar_vol
        
        # Micro position
        micro_dollar_vol = price * inst.trade_point_value * vol
        micro_contracts = risk_capital / micro_dollar_vol
        
        improvement = micro_contracts / full_contracts if full_contracts > 0 else 0
        
        print(f"{signal_sym:<8} {inst.trade_symbol:<8} ${price:>9,.2f} {vol:>7.1%} "
              f"{full_contracts:>11.1f} {micro_contracts:>11.1f} {improvement:>11.1f}x")

print("-" * 80)
print("Improvement = how many more contracts you can fine-tune with using micros")
# Out:
# ================================================================================
# POSITION SIZE GRANULARITY COMPARISON
# ================================================================================
# Account: $400,000 | Risk per trade: 1.0%
# --------------------------------------------------------------------------------
# Signal   Trade         Price      Vol    Full-Size        Micro  Improvement
# --------------------------------------------------------------------------------
# 6A       M6A      $     0.67    6.1%         1.0         9.7        10.0x
# 6B       M6B      $     1.34    5.8%         0.8         8.3        10.0x
# 6C       MCD      $     0.72    4.4%         1.3        12.6        10.0x
# 6E       M6E      $     1.17    4.4%         0.6         6.1        10.0x
# 6J       MJY      $     0.63    7.1%         0.7         7.1        10.0x
# 6S       MSF      $     1.27    6.7%         0.4         3.8        10.0x
# BRN      BRN      $    64.92   24.6%         0.3         0.3         1.0x
# CC       CC       $ 4,648.00   54.0%         0.2         0.2         1.0x
# CL       MCL      $    60.36   28.2%         0.2         2.4        10.0x
# CT       CT       $    64.34   12.0%         1.0         1.0         1.0x
# DX       DX       $    98.44    4.3%         0.9         0.9         1.0x
# ES       MES      $ 6,829.50   12.1%         0.1         1.0        10.0x
# FESX     FESX     $ 5,909.00   12.0%         0.6         0.6         1.0x
# FGBL     FGBL     $   127.97    2.9%         1.1         1.1         1.0x
# FGBM     FGBM     $   116.48    3.0%         1.1         1.1         1.0x
# FGBS     FGBS     $   106.89    0.6%         6.5         6.5         1.0x
# GC       MGC      $ 4,765.80   21.4%         0.0         0.4        10.0x
# HG       MHG      $   581.25   29.9%         0.0         0.0        10.0x
# NG       MNG      $     3.91   89.3%         0.1         1.1        10.0x
# NKD      NKD      $52,230.00   20.1%         0.1         0.1         1.0x
# NQ       MNQ      $25,129.25   17.2%         0.0         0.5        10.0x
# PL       PL       $ 2,450.50   62.4%         0.1         0.1         1.0x
# RB       MRB      $     1.82   28.8%         0.2         1.8        10.0x
# RTY      M2K      $ 2,658.70   18.0%         0.2         1.7        10.0x
# SB       SB       $    14.72   22.8%         1.1         1.1         1.0x
# VX       VXM      $    20.22   83.3%         0.2         2.4        10.0x
# YM       MYM      $48,666.00   11.8%         0.1         1.4        10.0x
# ZB       ZB       $   114.25    6.5%         0.5         0.5         1.0x
# ZC       MZC      $   423.75   19.8%         1.0         9.5        10.0x
# ZF       ZF       $   108.62    2.2%         1.7         1.7         1.0x
# ZL       MZL      $    52.56   19.6%         0.6         6.5        10.0x
# ZM       MZM      $   291.60   21.1%         0.7         6.5        10.0x
# ZN       ZN       $   111.42    3.3%         1.1         1.1         1.0x
# ZS       MZS      $ 1,053.00   16.7%         0.5         4.6        10.0x
# ZT       ZT       $   104.12    0.9%         2.1         2.1         1.0x
# ZW       MZW      $   510.25   19.6%         0.8         8.0        10.0x
# --------------------------------------------------------------------------------
# Improvement = how many more contracts you can fine-tune with using micros

# %%
# ==================== SAVE RESULTS ====================
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

results.to_csv(f"backtest_results_micros_{timestamp}.csv")
print(f"✓ Results saved: backtest_results_micros_{timestamp}.csv")

with open(f"metrics_micros_{timestamp}.json", 'w') as f:
    json.dump({k: float(v) if isinstance(v, (np.floating, np.integer)) else v 
               for k, v in metrics.items()}, f, indent=2)
print(f"✓ Metrics saved: metrics_micros_{timestamp}.json")

# Save instrument mapping
mapping_data = []
for inst in instruments:
    mapping_data.append({
        'signal_symbol': inst.signal_symbol,
        'trade_symbol': inst.trade_symbol,
        'name': inst.name,
        'sector': inst.sector,
        'signal_point_value': inst.signal_point_value,
        'trade_point_value': inst.trade_point_value,
        'trade_margin': inst.trade_margin,
        'granularity_factor': inst.granularity_factor,
        'is_micro': inst.is_micro,
    })

pd.DataFrame(mapping_data).to_csv(f"instrument_mapping_{timestamp}.csv", index=False)
print(f"✓ Mapping saved: instrument_mapping_{timestamp}.csv")
# Out:
# ✓ Results saved: backtest_results_micros_20260122_122535.csv
# ✓ Metrics saved: metrics_micros_20260122_122535.json
# ✓ Mapping saved: instrument_mapping_20260122_122535.csv
